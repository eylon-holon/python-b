# %%
from eylon.core import *
store_all_changes_to_github()
get_next_lesson()
# Out:
# From https://github.com/eylon-holon/python-b
#    24e2775..45f996f  main       -> origin/main
# Already up to date.
#
#
# [gosha-smeh 4c777eb] auto commit...
#  1 file changed, 7 insertions(+), 35 deletions(-)
# To https://github.com/eylon-holon/python-b
#    cfc9137..4c777eb  gosha-smeh -> gosha-smeh
# Merge made by the 'ort' strategy.
#  daf-ezer/vars-and-ops.ipynb | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)
# To https://github.com/eylon-holon/python-b
#    4c777eb..8f1f27a  gosha-smeh -> gosha-smeh
