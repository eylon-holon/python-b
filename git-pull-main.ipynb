# %%
from eylon.core import *
store_all_changes_to_github()
get_next_lesson()
# Out:
# From https://github.com/eylon-holon/python-b
#    943551d..1b1aaaa  main       -> origin/main
# Already up to date.
#
#
# [karin-bashari 2244ab9] auto commit...
#  3 files changed, 22 insertions(+), 64 deletions(-)
# To https://github.com/eylon-holon/python-b
#    fed3560..2244ab9  karin-bashari -> karin-bashari
# Auto-merging mafmars/python-b-2022.solution.ipynb
# Merge made by the 'ort' strategy.
#  mafmars/img/img_00550.png            | Bin 0 -> 36447 bytes
#  mafmars/python-b-2022.solution.ipynb |  19 ++++++++++---------
#  2 files changed, 10 insertions(+), 9 deletions(-)
#  create mode 100644 mafmars/img/img_00550.png
# To https://github.com/eylon-holon/python-b
#    2244ab9..4d37d4f  karin-bashari -> karin-bashari
