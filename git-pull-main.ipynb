# %%
from eylon.core import *
store_all_changes_to_github()
get_next_lesson()
# Out:
# From https://github.com/eylon-holon/python-b
#    61805c7..7e364b9  adir-biton        -> origin/adir-biton
#    f4862cc..321537c  asaf-charu        -> origin/asaf-charu
#    a9badb1..0580bf2  barel-sher        -> origin/barel-sher
#    b3d2b8a..e174598  elior-vais        -> origin/elior-vais
#    0fe55fd..6e7aee8  eliran-noorielyan -> origin/eliran-noorielyan
#    c45be7d..4621577  itay-beeri        -> origin/itay-beeri
#    63f3e6b..bc21e40  lian-aharon       -> origin/lian-aharon
#    d61cf38..734cbcd  liel-aloni        -> origin/liel-aloni
#    af558f0..67829ee  lionel-zvulunov   -> origin/lionel-zvulunov
#    6f9b3e1..a41545d  main              -> origin/main
#    d0d7378..45d428b  ofir-ywlzry       -> origin/ofir-ywlzry
#    e1b6b47..017f2ba  or-habas          -> origin/or-habas
#    252def6..f984a49  oriya-wilf        -> origin/oriya-wilf
#    c4ce9c6..3e6401b  yali-zivat        -> origin/yali-zivat
#    f3d8d33..dbc3d91  yuval-levi        -> origin/yuval-levi
# ...
