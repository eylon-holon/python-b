# %%
from eylon.core import *
store_all_changes_to_github()
get_next_lesson()
# Out:
# From https://github.com/eylon-holon/python-b
#    a053e99..bb44877  lian-levi      -> origin/lian-levi
#    090765d..0888d6d  main           -> origin/main
#    0afa357..d53d5e7  noam-banuz     -> origin/noam-banuz
#    fe93625..75e5687  oriya-wilf     -> origin/oriya-wilf
#    2e0f2a0..2937b97  ronalee-partuk -> origin/ronalee-partuk
#    c717336..d9d2b98  segev-gordin   -> origin/segev-gordin
#    6e3b10e..f72d985  yali-zivat     -> origin/yali-zivat
# Already up to date.
#
#
# [noa-romani fc3c2d3] auto commit...
#  3 files changed, 28 insertions(+), 53 deletions(-)
# To https://github.com/eylon-holon/python-b
#    84c4abb..fc3c2d3  noa-romani -> noa-romani
# Auto-merging mafmars/python-b-2022.solution.ipynb
# Merge made by the 'ort' strategy.
#  daf-ezer/algorithms.ipynb            | 300 ++++++++++++++++++++++++++++++++++-
#  daf-ezer/turtle.ipynb                |  20 +++
#  daf-ezer/vars-and-ops.ipynb          | 234 +++++++++++++++++----------
# ...
