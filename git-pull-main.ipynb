# %%
from eylon.core import *
store_all_changes_to_github()
get_next_lesson()
# Out:
# [eliran-noorielyan 5111c86] auto commit...
#  3 files changed, 73 insertions(+), 23 deletions(-)
# To https://github.com/eylon-holon/python-b
#    2ba1f39..5111c86  eliran-noorielyan -> eliran-noorielyan
# From https://github.com/eylon-holon/python-b
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# Everything up-to-date
