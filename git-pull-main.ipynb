# %%
from eylon.core import *
store_all_changes_to_github()
get_next_lesson()
# Out:
# From https://github.com/eylon-holon/python-b
#    86bd623..c0d3828  gosha-smeh      -> origin/gosha-smeh
#    bae5495..09d9c0a  ido-zur         -> origin/ido-zur
#    07efd89..4d37d4f  karin-bashari   -> origin/karin-bashari
#    a41545d..1b1aaaa  main            -> origin/main
#    939c210..0afa357  noam-banuz      -> origin/noam-banuz
#    9463d50..dc337a0  noam-frucsad    -> origin/noam-frucsad
#    8b78c5b..f0c7a16  noam-moshkovich -> origin/noam-moshkovich
#    f984a49..fe93625  oriya-wilf      -> origin/oriya-wilf
#    226984c..2e0f2a0  ronalee-partuk  -> origin/ronalee-partuk
#    9a1b4ab..8cf3abb  sahar-daniel    -> origin/sahar-daniel
#    b1fbd60..c717336  segev-gordin    -> origin/segev-gordin
# Already up to date.
#
#
# [noa-romani b01a2f7] auto commit...
#  4 files changed, 115 insertions(+), 111 deletions(-)
# To https://github.com/eylon-holon/python-b
#    509b112..b01a2f7  noa-romani -> noa-romani
# Auto-merging mafmars/python-b-2022.ipynb
# ...
