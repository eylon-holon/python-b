# %%
from eylon.core import *
store_all_changes_to_github()
get_next_lesson()
# Out:
# From https://github.com/eylon-holon/python-b
#    003fc30..abea45d  karin-bashari -> origin/karin-bashari
# Already up to date.
#
#
# [noa-romani 649a7ed] auto commit...
#  1 file changed, 36 insertions(+), 6 deletions(-)
# To https://github.com/eylon-holon/python-b
#    e1dec86..649a7ed  noa-romani -> noa-romani
# Already up to date.
# Everything up-to-date
