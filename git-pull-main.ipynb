# %%
from eylon.core import *
store_all_changes_to_github()
get_next_lesson()
# Out:
# From https://github.com/eylon-holon/python-b
#    0eb0e88..6f9b3e1  main       -> origin/main
# Already up to date.
#
#
# [elior-vais ff4f02d] auto commit...
#  1 file changed, 1 insertion(+), 76 deletions(-)
# To https://github.com/eylon-holon/python-b
#    e0b1e88..ff4f02d  elior-vais -> elior-vais
# Merge made by the 'ort' strategy.
#  mafmars/python-b--2022.ipynb | 39 +++++++++++++++++++++++++++++++++++++++
#  1 file changed, 39 insertions(+)
#  create mode 100644 mafmars/python-b--2022.ipynb
# To https://github.com/eylon-holon/python-b
#    ff4f02d..b3d2b8a  elior-vais -> elior-vais
