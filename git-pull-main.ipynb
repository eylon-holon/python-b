# %%
from eylon.core import *
store_all_changes_to_github()
get_next_lesson()
# Out:
# [liel-aloni 7ebee33] auto commit...
#  1 file changed, 19 insertions(+), 6 deletions(-)
# To https://github.com/eylon-holon/python-b
#    ac10830..7ebee33  liel-aloni -> liel-aloni
# From https://github.com/eylon-holon/python-b
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# Everything up-to-date
