# %%
from eylon.core import *
store_all_changes_to_github()
get_next_lesson()
# Out:
# From https://github.com/eylon-holon/python-b
#    bae5495..4d2ac1e  ido-zur         -> origin/ido-zur
#    07efd89..942c965  karin-bashari   -> origin/karin-bashari
#    a41545d..943551d  main            -> origin/main
#    9463d50..dc337a0  noam-frucsad    -> origin/noam-frucsad
#    8b78c5b..f0c7a16  noam-moshkovich -> origin/noam-moshkovich
#    226984c..075d6ae  ronalee-partuk  -> origin/ronalee-partuk
#    9a1b4ab..8cf3abb  sahar-daniel    -> origin/sahar-daniel
#    b1fbd60..c717336  segev-gordin    -> origin/segev-gordin
# Already up to date.
#
#
# [noam-banuz ed04ec3] auto commit...
#  2 files changed, 39 insertions(+), 42 deletions(-)
# To https://github.com/eylon-holon/python-b
#    b320a8e..ed04ec3  noam-banuz -> noam-banuz
# Merge made by the 'ort' strategy.
#  mafmars/mafmar-a.solution.ipynb      | 554 +++++++++++++++++++++++++++++
#  mafmars/python-b-2022.ipynb          |   2 +-
#  mafmars/python-b-2022.solution.ipynb | 662 +++++++++++++++++++++++++++++++++++
# ...
