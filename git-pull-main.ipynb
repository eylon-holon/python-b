# %%
from eylon.core import *
store_all_changes_to_github()
get_next_lesson()
# Out:
# From https://github.com/eylon-holon/python-b
#    f4862cc..321537c  asaf-charu        -> origin/asaf-charu
#    a9badb1..0580bf2  barel-sher        -> origin/barel-sher
#    0fe55fd..6e7aee8  eliran-noorielyan -> origin/eliran-noorielyan
#    bae5495..4d2ac1e  ido-zur           -> origin/ido-zur
#    c45be7d..4621577  itay-beeri        -> origin/itay-beeri
#    07efd89..942c965  karin-bashari     -> origin/karin-bashari
#    bc21e40..228930c  lian-aharon       -> origin/lian-aharon
#    c920aa8..a053e99  lian-levi         -> origin/lian-levi
#    734cbcd..edd0ac2  liel-aloni        -> origin/liel-aloni
#    67829ee..55b7672  lionel-zvulunov   -> origin/lionel-zvulunov
#    a41545d..943551d  main              -> origin/main
#    71f71a8..509b112  noa-romani        -> origin/noa-romani
#    939c210..0afa357  noam-banuz        -> origin/noam-banuz
#    9463d50..dc337a0  noam-frucsad      -> origin/noam-frucsad
#    8b78c5b..f0c7a16  noam-moshkovich   -> origin/noam-moshkovich
# ...
