# %%
from eylon.core import *
store_all_changes_to_github()
get_next_lesson()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from eylon.core import *
#       2 store_all_changes_to_github()
#       3 get_next_lesson()
#
# File /workspaces/python-b/eylon/core.py:6
#       3 import inspect
#       4 import json
# ----> 6 from eylon.utils import *
#       7 from eylon.post import post
#       8 from eylon.classwork import ClassWork
#
# File /workspaces/python-b/eylon/utils.py:4
#       1 import os
#       2 import traceback
# ----> 4 from git import Repo
#       7 def fname(f):
#       8     return f"{f.__name__}()"
#
# ModuleNotFoundError: No module named 'git'
