# %%
from eylon.core import *
store_all_changes_to_github()
get_next_lesson()
# Out:
# [segev-gordin e120d66] auto commit...
#  1 file changed, 18 insertions(+), 5 deletions(-)
# To https://github.com/eylon-holon/python-b
#    80cfdd6..e120d66  segev-gordin -> segev-gordin
# From https://github.com/eylon-holon/python-b
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# Everything up-to-date
