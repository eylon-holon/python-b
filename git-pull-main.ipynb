# %%
from eylon.core import *
store_all_changes_to_github()
get_next_lesson()
# Out:
# From https://github.com/eylon-holon/python-b
#    f15c2ba..1f08101  main       -> origin/main
# Already up to date.
#
#
# [gosha-smeh 7e7545d] auto commit...
#  1 file changed, 7 insertions(+), 7 deletions(-)
# To https://github.com/eylon-holon/python-b
#    76a2ce7..7e7545d  gosha-smeh -> gosha-smeh
# Merge made by the 'ort' strategy.
#  daf-ezer/vars-and-ops.ipynb | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)
# To https://github.com/eylon-holon/python-b
#    7e7545d..30b765b  gosha-smeh -> gosha-smeh
