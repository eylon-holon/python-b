# %%
from eylon.core import *
store_all_changes_to_github()
get_next_lesson()
# Out:
# From https://github.com/eylon-holon/python-b
#    45f996f..a934ab8  main       -> origin/main
# Already up to date.
#
#
# [gosha-smeh 4af254b] auto commit...
#  1 file changed, 17 insertions(+), 7 deletions(-)
# To https://github.com/eylon-holon/python-b
#    8f1f27a..4af254b  gosha-smeh -> gosha-smeh
# Merge made by the 'ort' strategy.
#  daf-ezer/vars-and-ops.ipynb | 1 +
#  1 file changed, 1 insertion(+)
# To https://github.com/eylon-holon/python-b
#    4af254b..5d25631  gosha-smeh -> gosha-smeh
