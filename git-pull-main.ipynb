# %%
from eylon.core import *
store_all_changes_to_github()
get_next_lesson()
# Out:
# Already up to date.
#
#
# [yair-wiener 6a428fc] auto commit...
#  6 files changed, 214 insertions(+), 100 deletions(-)
# To https://github.com/eylon-holon/python-b
#    3149096..6a428fc  yair-wiener -> yair-wiener
# Already up to date.
# Everything up-to-date
