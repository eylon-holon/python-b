# %%
from eylon.core import *
store_all_changes_to_github()
get_next_lesson()
# Out:
# From https://github.com/eylon-holon/python-b
#    1f08101..ad2a2c7  main       -> origin/main
# Already up to date.
#
#
# [gosha-smeh 5227905] auto commit...
#  1 file changed, 6 insertions(+), 6 deletions(-)
# To https://github.com/eylon-holon/python-b
#    30b765b..5227905  gosha-smeh -> gosha-smeh
# Merge made by the 'ort' strategy.
#  daf-ezer/vars-and-ops.ipynb | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)
# To https://github.com/eylon-holon/python-b
#    5227905..1f91912  gosha-smeh -> gosha-smeh
