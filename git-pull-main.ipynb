# %%
from eylon.core import *
store_all_changes_to_github()
get_next_lesson()
# Out:
# From https://github.com/eylon-holon/python-b
#    a934ab8..5584f2d  main       -> origin/main
# Already up to date.
#
#
# [gosha-smeh 1cb1c38] auto commit...
#  1 file changed, 8 insertions(+), 8 deletions(-)
# To https://github.com/eylon-holon/python-b
#    5d25631..1cb1c38  gosha-smeh -> gosha-smeh
# Merge made by the 'ort' strategy.
#  daf-ezer/vars-and-ops.ipynb | 10 +++++-----
#  1 file changed, 5 insertions(+), 5 deletions(-)
# To https://github.com/eylon-holon/python-b
#    1cb1c38..51e4803  gosha-smeh -> gosha-smeh
