# %%
from eylon.core import *
store_all_changes_to_github()
get_next_lesson()
# Out:
# From https://github.com/eylon-holon/python-b
#    1b1aaaa..24e2775  main           -> origin/main
#    509b112..73836f0  noa-romani     -> origin/noa-romani
#    075d6ae..2e0f2a0  ronalee-partuk -> origin/ronalee-partuk
#    9e3d415..6e3b10e  yali-zivat     -> origin/yali-zivat
# Already up to date.
#
#
# [gosha-smeh c9da31e] auto commit...
#  2 files changed, 18 insertions(+), 22 deletions(-)
# To https://github.com/eylon-holon/python-b
#    c0d3828..c9da31e  gosha-smeh -> gosha-smeh
# Merge made by the 'ort' strategy.
#  05-strings-01.ipynb             |  41 ++-
#  daf-ezer/algorithms.ipynb       |  99 ++++++
#  daf-ezer/data-structures.ipynb  |  27 ++
#  daf-ezer/turtle.ipynb           |  43 +++
#  daf-ezer/vars-and-ops.ipynb     | 631 ++++++++++++++++++++++++++++++++++++++
#  mafmars/mafmar-a.solution.ipynb |  18 +-
#  mafmars/mafmar-b.ipynb          | 663 ++++++++++++++++++++++++++++++++++++++++
#  tests/tests.2.ipynb             | 147 +++++++++
# ...
