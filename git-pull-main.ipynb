# %%
from eylon.core import *
store_all_changes_to_github()
get_next_lesson()
# Out:
# Already up to date.
#
#
# [eliran-noorielyan 0fe55fd] auto commit...
#  3 files changed, 48 insertions(+), 20 deletions(-)
# To https://github.com/eylon-holon/python-b
#    e25139c..0fe55fd  eliran-noorielyan -> eliran-noorielyan
# Already up to date.
# Everything up-to-date
