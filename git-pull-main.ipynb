# %%
from eylon.core import *
store_all_changes_to_github()
get_next_lesson()
# Out:
# From https://github.com/eylon-holon/python-b
#    5584f2d..f15c2ba  main       -> origin/main
# Already up to date.
#
#
# [gosha-smeh dee197c] auto commit...
#  1 file changed, 8 insertions(+), 8 deletions(-)
# To https://github.com/eylon-holon/python-b
#    51e4803..dee197c  gosha-smeh -> gosha-smeh
# Merge made by the 'ort' strategy.
#  daf-ezer/vars-and-ops.ipynb | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)
# To https://github.com/eylon-holon/python-b
#    dee197c..76a2ce7  gosha-smeh -> gosha-smeh
