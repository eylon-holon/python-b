# %%
str = "0123456789ABCDEF"
print(str[0])
print(str[1])
print(str[-1])
print(str[-2])
# Out:
# 0
# 1
# F
# E

# %% [markdown]
# מה העבדל בין גישה לאותיות מהתחלה ומהסוף (איפו האינדקס מתחיל בשני המקרים)?
#
# תשובה: בהתחלה זה מתחיל מ-0 ובסוף זה מתחיל ממינוס אחד

# %%
str = "0123456789ABCDEF"
print(len(str))
# Out:
# 16

# %% [markdown]
# len - מה מחזירה פונקציה?
#
# תשובה: היא סופרת את מספר המספרים\אותיות

# %%
str = "0123456789ABCDEF"
print(str[len(str)-1])
print(str[-1])
# Out:
# F
# F

# %% [markdown]
# למה זה מדפיס אותה אות?
#
# תשובה: מפני שבראשון הקוד סופר את המספר האותיות והספרות ואז מחסיר מהסוף ובשני הוא גם מסחיר מהסוף

# %%
name = input("Enter your name: ")
print("Hello " + name + "!")
# Out:
# Hello no!

# %% [markdown]
# מה פעולה + עושה עם המחרוזות?
#
# תשובה: זה מחבר את המילה עם מה שכותבים לקוד

# %%
name = input("Enter your name: ")
print("Hello "*2 + name*2)
# Out:
# Hello Hello NONO

# %% [markdown]
# מה פעולה * עושה עם המחרוזות?
#
# תשובה: היא מכפילה את המילה פעמיים

# %%
str = "0123456789ABCDEF"
print(str[0:len(str):1])
print(str[0::1])
print(str[0::])
print(str[::])
# Out:
# 0123456789ABCDEF
# 0123456789ABCDEF
# 0123456789ABCDEF
# 0123456789ABCDEF

# %% [markdown]
# איך זה שכל השורות מדפיסות אותו דבר?<br>
# מה המשמעות של ערכים דפולטיים (default)?
#
# תשובה: זה מדפיס אותו הדבר כי בכולם זה אומר לעשות קפיצות של אחד ולסיים את זה בסוף המשפט.
# הערכים זה אומר שלא צריך להציב את המיקומים ושהמחשב מתקדם לבד בקפיצות של אחד עד סוף המשפט

# %%
str = "0123456789ABCDEF"
print(str[::])
# Out:
# 0123456789ABCDEF

# %% [markdown]
# מהם הערכים הדפולטיים במקרה הזה?
#
# תשובה: מתי שזה מתחיל, מספר הצעדים ומתי זה נגמר
# שזה מתחיל ב-0 מספר הצעדים הוא אחד וזה נגמר בסוף המשפט

# %%
str = "0123456789ABCDEF"
print(str[0::])
print(str[1::])
print(str[5::])
# Out:
# 0123456789ABCDEF
# 123456789ABCDEF
# 56789ABCDEF

# %% [markdown]
# מה המשמעות של מספר הראשון בתווך?
#
# תשובה: זה אומר מאיזה מיקום זה מתחיל

# %%
str = "0123456789ABCDEF"
print(str[:1:])
print(str[:2:])
print(str[:5:])
# Out:
# 0
# 01
# 01234

# %% [markdown]
# מה המשמעות של מספר השני בתווך?
#
# תשובה: זה אומר באיזה מיקום זה עוצר

# %%
str = "0123456789ABCDEF"
print(str[::1])
print(str[::2])
print(str[::3])
# Out:
# 0123456789ABCDEF
# 02468ACE
# 0369CF

# %% [markdown]
# מה המשמעות של מספר השלישי בתווך?
#
# תשובה: זה אומר מה מספר הצעדים

# %%
str = "0123456789ABCDEF"
print(str[::-1])
print(str[len(str)::-1])
# Out:
# FEDCBA9876543210
# FEDCBA9876543210

# %% [markdown]
# מה הערכים הדפולטיים עכשיו?<br>
# מה לדעתך גורם להבדל?
#
# תשובה: מתי זה מתחיל ומתי שזה נגמר. מה שגורם להבדל זה מספר הצעדים שהוא במינוס

# %%
word = input("Enter word: ")
print(word)
print(word[::-1])
print(word == word[::-1])
# Out:
# שלום
# םולש
# False

# %% [markdown]
# true - מתי שורה שלישית מדפיסה?<br>
# מה זה אומר על המילה?
#
# תשובה: זה מדפיס את המילה הזאת מתי שהמילה בהפוך מתאימה למילה הרגילה.
# זה אומר על המילה שהיא אותה מילה גם ברגיל וגם בהפוך

# %%
str = "0123456789ABCDEF"
print(str[0::2])
print(str[1::2])
print(str[5:10:1])
# Out:
# 02468ACE
# 13579BDF
# 56789

# %% [markdown]
# תשלימו את הקוד כך שיודפס<br>
# 02468ACE<br>
# 13579BDF<br>
# 56789

# %%
str = "0123456789ABCDEF"
print("1" in str)
print("12" in str)
print("ABC" in str)
print("135" in str)
# Out:
# True
# True
# True
# False

# %% [markdown]
# in - מה האופרטור מחזיר?
#
# תשובה: זה אומר אם המילה שכתבו בתוך המשפט או לא

# %%
print("122333444455555".count("1"))
print("122333444455555".count("2"))
print("122333444455555".count("4"))
print("122333444455555".count("6"))
# Out:
# 1
# 2
# 4
# 0

# %% [markdown]
# count - מה הפונקציה מחזירה?
#
# תשובה: זה סופר מספרים

# %%
str = "0123456789ABCDEF"
print(str.find("0"))
print(str.find("01"))
print(str.find("789"))
print(str.find("EF"))
print(str.find("FE"))
# Out:
# 0
# 0
# 7
# 14
# -1

# %% [markdown]
# find - מה הפונקציה מחזירה?
#
# תשובה: זה אומר באיזה מיקום המספר נמצא

# %%
str = "0123456789ABCDEF"
print(str.startswith("0123"))
print(str.startswith("1234"))
# Out:
# True
# False

# %% [markdown]
# startswith - מה הפונקציה מחזירה?
#
# תשובה: זה בודק אם הקוד מתחיל עם המספר שכתבו

# %%
str = "0123456789ABCDEF"
print(str.endswith("CDEF"))
print(str.endswith("AB"))
# Out:
# True
# False

# %% [markdown]
# endswith - תשלימו את קוד כך שיודפס<br>
# true<br>
# false

# %%
s1 = "Hello name!"
name = input("Enter your name: ")
s2 = s1.replace("name", name)
print(s2)
# Out:
# Hello no!

# %% [markdown]
# replace - מה הפונקציה מחזירה?
#
# .תשובה: זה נותן את השם שמזינים המקום את המילה שם באנגלית

# %%
print("1234".isnumeric())
print("1234".isalpha())
print("abcd".isnumeric())
print("abcd".isalpha())
# Out:
# True
# False
# False
# True

# %% [markdown]
# isnumeric(), isalpha()<br>
# מה הפונקציות מחזירות?
#
# .תשובה: מתי שזה מספר ושואלים אם זה מספר אז זה אומר שזה נכון ומתי זה מילה ושואלים שזה מילה אז זה מחזיר נכון

# %%
print("-1234".isnumeric())
print("-1234".isalpha())
# Out:
# False
# False

# %% [markdown]
# false - למה שניהם החזירו?
#
# .תשובה: כי זה במינוסים

# %%
print("abcdef".upper())
print("ABCDEF".lower())
# Out:
# ABCDEF
# abcdef

# %% [markdown]
# upper(), lower()<br>
# מה הפונקציות מחזירות?
#
# .תשובה: הן הופכות את האותיות הקטנות לגדולות ואת האותיות הגדולות לקטנות

# %%
s1 = "One two THree"
s2 = "one TWO three"
s1=("one two three".upper())
s2=("one two three".upper())
print(s1 == s2)
print(s1 == s2)
# Out:
# True
# True

# %% [markdown]
# תשתמשו בפונקציות<br>
# upper() lower()<br>
# כך שיודפס<br>
# true<br>
# true
