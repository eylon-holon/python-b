# %%
str = "0123456789ABCDEF"
print(str[0])
print(str[1])
print(str[-1])
print(str[-2])
# Out:
# 0
# 1
# F
# E

# %% [markdown]
# מה העבדל בין גישה לאותיות מהתחלה ומהסוף (איפו האינדקס מתחיל בשני המקרים)?
# האינדקסים מתחילים מ-0 ומ
# (-1)מהסוף .

# %%
str = "0123456789ABCDEF"
print(len(str))
# Out:
# 16

# %% [markdown]
# len - מה מחזירה פונקציה?
# len אורך המחרוזת

# %%
str = "0123456789ABCDEF"
print(str[len(str)-1])
print(str[-1])
# Out:
# F
# F

# %% [markdown]
# למה זה מדפיס אותה אות? י
# אותה פקודה רק כתובה בצורה שונה

# %%
name = input("Enter your name: ")
print("Hello " + name + "!")

# %% [markdown]
# מה פעולה + עושה עם המחרוזות?
# מחברת רת המחרוזת למשתנה או למחרוזת אחרת

# %%
name = input("Enter your name: ")
print("Hello "*2 + name*2)

# %% [markdown]
# מה פעולה * עושה עם המחרוזות? כותבת את המחרוזת פעמיים

# %%
str = "0123456789ABCDEF"
print(str[0:len(str):1])
print(str[0::1])
print(str[0::])
print(str[::])
print(str[:])

# %% [markdown]
# איך זה שכל השורות מדפיסות אותו דבר?<br>
# מה המשמעות של ערכים דפולטיים (default)?
# השורות מדפיסות את אותו הדב מכיוון שיש לה ערכים דיפולטים

# %%
str = "0123456789ABCDEF"
print(str[::])

# %% [markdown]
# מהם הערכים הדפולטיים במקרה הזה? 0:16:1

# %%
str = "0123456789ABCDEF"
print(str[0::])
print(str[1::])
print(str[5::])

# %% [markdown]
# מה המשמעות של מספר הראשון בתווך? מתי מתחילים את הלולאה

# %%
str = "0123456789ABCDEF"
print(str[:1:])
print(str[:2:])
print(str[:5:])

# %% [markdown]
# מה המשמעות של מספר השני בתווך? מתי מסימים

# %%
str = "0123456789ABCDEF"
print(str[::1])
print(str[::2])
print(str[::3])

# %%
str = "0123456789ABCDEF"
print(str[:])
print(str[1:4])
print(str[4:])
print(str[:3])

# %% [markdown]
#  מה המשמעות של מספר השלישי בתווך? המקפצה

# %%
str = "0123456789ABCDEF"
print(str[::-1])
print(str[len(str)::-1])

# %% [markdown]
# מה הערכים הדפולטיים עכשיו?<br> לולאה בסדר יורד
# מה לדעתך גורם להבדל?

# %%
str = "0123456789ABCDEF"
print(str[-1:-5:-1])
print(str[-5:-1])
print(str[-5:])
print(str[:-5])
print("[" + str[-1:-5] + "]")

# %% [markdown]
# למה בשורה אחרונה לא מודפס כלום?

# %%
word = input("Enter word: ")
print(word)
print(word[::-1])
print(word == word[::-1])

# %% [markdown]
# true - מתי שורה שלישית מדפיסה?<br> רק שהמילה היא פולינדרום וזה אומר שאפשר להפוך אותנה וזה יהיה אותה מילה
# מה זה אומר על המילה?

# %%
str = "0123456789ABCDEF"
print(str[::2])
print(str[1:16:2])
print(str[5:10:])

# %% [markdown]
# תשלימו את הקוד כך שיודפס<br>
# 02468ACE<br>
# 13579BDF<br>
# 56789

# %%
str = "0123456789ABCDEF"
print("1" in str)
print("12" in str)
print("ABC" in str)
print("135" in str)

# %% [markdown]
# in - מה האופרטור מחזיר?
# האם המספירם או האותיות שנחנו נמצאים במחרוזת

# %%
print("122333444455555".count("1"))
print("122333444455555".count("2"))
print("122333444455555".count("4"))
print("122333444455555".count("6"))

# %% [markdown]
#  מספר הפעמים מספר או אות נמצא במחרוזת count - מה הפונקציה מחזירה?

# %%
str = "0123456789ABCDEF"
print(str.find("0"))
print(str.find("01"))
print(str.find("789"))
print(str.find("EF"))
print(str.find("FE"))

# %% [markdown]
#  איפה רצף המספרים נמצא במחרוזת find - מה הפונקציה מחזירה?

# %%
str = "0123456789ABCDEF"
print(str.startswith("0123"))
print(str.startswith("1234"))

# %% [markdown]
# startswith - מה הפונקציה מחזירה?

# %%
str = "0123456789ABCDEF"
print(str.endswith())
print(str.endswith())

# %% [markdown]
# endswith - תשלימו את קוד כך שיודפס<br>
# true<br>
# false

# %%
s1 = "Hello name!"
name = input("Enter your name: ")
s2 = s1.replace("name", name)
print(s2)

# %% [markdown]
# replace - מה הפונקציה מחזירה?

# %%
print("1234".isnumeric())
print("1234".isalpha())
print("abcd".isnumeric())
print("abcd".isalpha())

# %% [markdown]
# isnumeric(), isalpha()<br>
# מה הפונקציות מחזירות?

# %%
print("-1234".isnumeric())
print("-1234".isalpha())

# %% [markdown]
# false - למה שניהם החזירו?

# %%
print("abcdef".upper())
print("ABCDEF".lower())

# %% [markdown]
# upper(), lower()<br>
# מה הפונקציות מחזירות?

# %%
s1 = "One two THree"
s2 = "one TWO three"
print(s1 == s2)
print(s1 == s2)

# %% [markdown]
# תשתמשו בפונקציות<br>
# upper() lower()<br>
# כך שיודפס<br>
# true<br>
# true
