# %%
str = "0123456789ABCDEF"
print(str[0])
print(str[1])
print(str[-1])
print(str[-2])
# Out:
# 0
# 1
# F
# E

# %% [markdown]
# מספרים שליליים אומרים ללכת מהסוף להתחלה

# %%
str = "0123456789ABCDEF"
print(len(str))
# Out:
# 16

# %% [markdown]
# הפונקציה len מחזירה את אורך ה string

# %%
str = "0123456789ABCDEF"
print(str[len(str)-1])
print(str[-1])
# Out:
# F
# F

# %% [markdown]
# זה מדפיס אותה אות כי len(str)= 16 ו len(str)-1 זה גם 16

# %%
name = input("Enter your name: ")
print("Hello " + name + "!")
# Out:
# Hello א!

# %% [markdown]
# פעולת הפלוס משלבת סטרינגים ויוצרת סטרינג חדש

# %%
name = input("Enter your name: ")
print("Hello "*2 + name*2)

# %% [markdown]
# מה פעולה * עושה עם המחרוזות? (היא מדפיסה את הסטרנגים מספר הפעמים המצוין בפעולת הכפל)

# %%
str = "0123456789ABCDEF"
print(str[0:len(str):1])
print(str[0::1])
print(str[0::])
print(str[::])
# Out:
# 0123456789ABCDEF
# 0123456789ABCDEF
# 0123456789ABCDEF
# 0123456789ABCDEF

# %% [markdown]
# איך זה שכל השורות מדפיסות אותו דבר?<br>
# מה המשמעות של ערכים דפולטיים (default)? (בגלל שלא נכתב כלום בפונקציה היא משתשמשת בערכי הברירת המחדל (הערכים של הפונקציה הראשונה))

# %%
str = "0123456789ABCDEF"
print(str[::])
# Out:
# 0123456789ABCDEF

# %% [markdown]
# מהם הערכים הדפולטיים במקרה הזה? )b=0, e=(len(str), step=1

# %%
str = "0123456789ABCDEF"
print(str[0::])
print(str[1::])
print(str[5::])

# %% [markdown]
# מה המשמעות של מספר הראשון בתווך? (beginning, מאיזה אינקס להתחיל את הפונקציה)

# %%
str = "0123456789ABCDEF"
print(str[:1:])
print(str[:2:])
print(str[:5:])

# %% [markdown]
# מה המשמעות של מספר השני בתווך? )end, עד איזה נקודה למחשב ליישם את הפונקציה

# %%
str = "0123456789ABCDEF"
print(str[::1])
print(str[::2])
print(str[::3])

# %% [markdown]
# מה המשמעות של מספר השלישי בתווך?
# ת. step, באיזה רווחים הפונקציה מדלגת על ערכים

# %%
str = "0123456789ABCDEF"
print(str[::-1])
print(str[len(str)::-1])
# Out:
# FEDCBA9876543210
# FEDCBA9876543210

# %% [markdown]
# מה הערכים הדפולטיים עכשיו?<br>
# מה לדעתך גורם להבדל?
# ת.

# %%
word = input("Enter word: ")
print(word)
print(word[::-1])
print(word == word[::-1])
# Out:
# idoodi
# idoodi
# True

# %% [markdown]
# true - מתי שורה שלישית מדפיסה?<br>
# מה זה אומר על המילה?
# השורה השלישית תדפיס true כאשר המילה היא פלינדרום
# (היא מבוטאת אותו הדבר משתי כייוני הקריאה)

# %%
str = "0123456789ABCDEF"
print(str[0:len(str):2])
print(str[0:])
print(str[])
# Out:
#   Cell In[3], line 3
#     print(str[])
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# תשלימו את הקוד כך שיודפס<br>
# 02468ACE<br>
# 13579BDF<br>
# 56789

# %%
str = "0123456789ABCDEF"
print("1" in str)
print("12" in str)
print("ABC" in str)
print("135" in str)
# Out:
# True
# True
# True
# False

# %% [markdown]
# in - מה האופרטור מחזיר?
# ת. בודק אם יש לפחות מקרה אחד של אות מסוימת בstring

# %%
print("122333444455555".count("1"))
print("122333444455555".count("2"))
print("122333444455555".count("4"))
print("122333444455555".count("6"))
# Out:
# 1
# 2
# 4
# 0

# %% [markdown]
# count - מה הפונקציה מחזירה?
# ת. סופרת כמה פעם אות מסוימת נמצאת בstring

# %%
str = "0123456789ABCDEF"
print(str.find("0"))
print(str.find("01"))
print(str.find("789"))
print(str.find("EF"))
print(str.find("FE"))
# Out:
# 0
# 0
# 7
# 14
# -1

# %% [markdown]
# find - מה הפונקציה מחזירה?
# ת. איפה רצף מסוים במיתר מתחיל

# %%
str = "0123456789ABCDEF"
print(str.startswith("0123"))
print(str.startswith("1234"))
# Out:
# True
# False

# %% [markdown]
# startswith - מה הפונקציה מחזירה?
# ת. בודקת אם המיתר מתחיל עם רצף מסוים

# %%
str = "0123456789ABCDEF"
print(str.endswith("DEF"))
print(str.endswith("123"))
# Out:
# True
# False

# %% [markdown]
# endswith - תשלימו את קוד כך שיודפס<br>
# true<br>
# false

# %%
s1 = "Hello name!"
name = input("Enter your name: ")
s2 = s1.replace("name", name)
print(s2)
# Out:
# Hello !

# %% [markdown]
# replace - מה הפונקציה מחזירה? מחליפה חלק מהתבנית בקלט של שורה 2

# %%
print("1234".isnumeric())
print("1234".isalpha())
print("abcd".isnumeric())
print("abcd".isalpha())
# Out:
# True
# False
# False
# True

# %% [markdown]
# isnumeric(), isalpha()<br>
# מה הפונקציות מחזירות?
# ת. הראשונה בודקת אם הקלט מספרי, השנייה אם הוא אלפבתי

# %%
print("-1234".isnumeric())
print("-1234".isalpha())
# Out:
# False
# False

# %% [markdown]
# false - למה שניהם החזירו?
# פעם אחת כי "-" נחשב כאות לא מספרי למחשב, פעם שנייה כי "1234" לא אלפבתי

# %%
print("abcdef".upper())
print("ABCDEF".lower())
# Out:
# ABCDEF
# abcdef

# %% [markdown]
# upper(), lower()<br>
# מה הפונקציות מחזירות?
# ת. הראשונה הופכת

# %%
s1 = "One two THree"
s2 = "one TWO three"
print(s1 == s2)
print(s1 == s2)

# %% [markdown]
# תשתמשו בפונקציות<br>
# upper() lower()<br>
# כך שיודפס<br>
# true<br>
# true
