# %%
str = "0123456789ABCDEF"
print(str[0])
print(str[1])
print(str[-1])
print(str[-2])
# Out:
# 0
# 1
# F
# E

# %% [markdown]
# מה העבדל בין גישה לאותיות מהתחלה ומהסוף (איפו האינדקס מתחיל בשני המקרים)?
# ההבדל הוא שזה ידפיס את המספרים/אותיות מהתחלה או מהסוף

# %%
str = "0123456789ABCDEF"
print(len(str))
# Out:
# 16

# %% [markdown]
#  len - מה מחזירה פונקציה?
# הפונקציה מחזירה את כמות המספרים ואאותיות בסדר

# %%
str = "0123456789ABCDEF"
print(str[len(str)-1])
print(str[-1])
# Out:
# F
# F

# %% [markdown]
# למה זה מדפיס אותה אות?

# %%
name = input("Enter your name: ")
print("Hello " + name + "!")
# Out:
# Hello Noam!

# %% [markdown]
# מה פעולה + עושה עם המחרוזות?
# הפעולה עושה משפט שמברך את הבן אדם

# %%
name = input("Enter your name: ")
print("Hello "*2 + name*2)
# Out:
# Hello Hello NOAMNOAM

# %% [markdown]
# מה פעולה * עושה עם המחרוזות?
# מברחת שלום פעמיים עם השם

# %%
str = "0123456789ABCDEF"
print(str[0:len(str):1])
print(str[0::1])
print(str[0::])
print(str[::])
# Out:
# 0123456789ABCDEF
# 0123456789ABCDEF
# 0123456789ABCDEF
# 0123456789ABCDEF

# %% [markdown]
# איך זה שכל השורות מדפיסות אותו דבר?<br>
# מה המשמעות של ערכים דפולטיים (default)?

# %%
str = "0123456789ABCDEF"
print(str[::])
# Out:
# 0123456789ABCDEF

# %% [markdown]
# מהם הערכים הדפולטיים במקרה הזה?
# 0:1:1

# %%
str = "0123456789ABCDEF"
print(str[0::])
print(str[1::])
print(str[5::])
# Out:
# 0123456789ABCDEF
# 123456789ABCDEF
# 56789ABCDEF

# %% [markdown]
# מה המשמעות של מספר הראשון בתווך?
# המשמעות היא איזה מספר הוא מתחיל את ההדפסה

# %%
str = "0123456789ABCDEF"
print(str[:1:])
print(str[:2:])
print(str[:5:])
# Out:
# 0
# 01
# 01234

# %% [markdown]
# מה המשמעות של מספר השני בתווך?
#  איזה מספר הוא יסתיים אם

# %%
str = "0123456789ABCDEF"
print(str[::1])
print(str[::2])
print(str[::3])
# Out:
# 0123456789ABCDEF
# 02468ACE
# 0369CF

# %% [markdown]
# מה המשמעות של מספר השלישי בתווך?
# קפיצת המספרים

# %%
str = "0123456789ABCDEF"
print(str[::-1])
print(str[len(str)::-1])
# Out:
# FEDCBA9876543210
# FEDCBA9876543210

# %% [markdown]
# מה הערכים הדפולטיים עכשיו?<br>
# מה לדעתך גורם להבדל?

# %%
word = input("Enter word: ")
print(word)
print(word[::-1])
print(word == word[::-1])
# Out:
# True

# %% [markdown]
# true - מתי שורה שלישית מדפיסה?<br>
# מה זה אומר על המילה?

# %%
str = "0123456789ABCDEF"
print(str[])
print(str[])
print(str[])
# Out:
#   Cell In[13], line 2
#     print(str[])
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# תשלימו את הקוד כך שיודפס<br>
# 02468ACE<br>
# 13579BDF<br>
# 56789

# %%
str = "0123456789ABCDEF"
print("1" in str)
print("12" in str)
print("ABC" in str)
print("135" in str)

# %% [markdown]
# in - מה האופרטור מחזיר?

# %%
print("122333444455555".count("1"))
print("122333444455555".count("2"))
print("122333444455555".count("4"))
print("122333444455555".count("6"))

# %% [markdown]
# count - מה הפונקציה מחזירה?

# %%
str = "0123456789ABCDEF"
print(str.find("0"))
print(str.find("01"))
print(str.find("789"))
print(str.find("EF"))
print(str.find("FE"))

# %% [markdown]
# find - מה הפונקציה מחזירה?

# %%
str = "0123456789ABCDEF"
print(str.startswith("0123"))
print(str.startswith("1234"))

# %% [markdown]
# startswith - מה הפונקציה מחזירה?

# %%
str = "0123456789ABCDEF"
print(str.endswith())
print(str.endswith())

# %% [markdown]
# endswith - תשלימו את קוד כך שיודפס<br>
# true<br>
# false

# %%
s1 = "Hello name!"
name = input("Enter your name: ")
s2 = s1.replace("name", name)
print(s2)

# %% [markdown]
# replace - מה הפונקציה מחזירה?

# %%
print("1234".isnumeric())
print("1234".isalpha())
print("abcd".isnumeric())
print("abcd".isalpha())

# %% [markdown]
# isnumeric(), isalpha()<br>
# מה הפונקציות מחזירות?

# %%
print("-1234".isnumeric())
print("-1234".isalpha())

# %% [markdown]
# false - למה שניהם החזירו?

# %%
print("abcdef".upper())
print("ABCDEF".lower())

# %% [markdown]
# upper(), lower()<br>
# מה הפונקציות מחזירות?

# %%
s1 = "One two THree"
s2 = "one TWO three"
print(s1 == s2)
print(s1 == s2)

# %% [markdown]
# תשתמשו בפונקציות<br>
# upper() lower()<br>
# כך שיודפס<br>
# true<br>
# true
