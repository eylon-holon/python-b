# %%
str = "0123456789ABCDEF"
print(str[0])
print(str[1])
print(str[-1])
print(str[-2])
# Out:
# 0
# 1
# F
# E

# %% [markdown]
# כשמתחילים מההתחלה מתחיליפ מאפס ועולים (מספרים חיוביים) וכשמהסוף במיקום זהו מספר שמתחיל ממתחת לאפס ומטה (מספרים שליליים)

# %%
str = "0123456789ABCDEF"
print(len(str))
# Out:
# 16

# %% [markdown]
# את אורך המחרוזת(כמה מספרים מופיעים בה) (את כמות המיקומים)

# %%
str = "0123456789ABCDEF"
print(str[len(str)-1])
print(str[-1])
# Out:
# F
# F

# %% [markdown]
# כי זה אותו מיקום

# %%
name = input("Enter your name: ")
print("Hello" + name + "!")
# Out:
# Helloliel!

# %% [markdown]
# היא מחברת ויוצרת מחרוזת חדשה

# %%
name = input("Enter your name: ")
print("Hello "*2 + name*2)
# Out:
# Hello Hello ליאלליאל

# %% [markdown]
# מכפילה את השם ויוצרת מחרוזת חדשה

# %%
str = "0123456789ABCDEF"
print(str[0:len(str):1])
print(str[0::1])
print(str[0::])
print(str[::])
# Out:
# 0123456789ABCDEF
# 0123456789ABCDEF
# 0123456789ABCDEF
# 0123456789ABCDEF

# %% [markdown]
# כי לא מוצב כלום אז הוא מציב איך שרצונו ורצונו זה הבסיסי, כמו בשורה הראשונה של print
# מספרים שפייטון משלים באוטומטיות

# %%
str = "0123456789ABCDEF"
print(str[::])
# Out:
# 0123456789ABCDEF

# %% [markdown]
# 16- והסוףהאורך
# 0-ההתחלה
# 1-הקפיצות

# %%
str = "0123456789ABCDEF"
print(str[0::])
print(str[1::])
print(str[5::])
# Out:
# 0123456789ABCDEF
# 123456789ABCDEF
# 56789ABCDEF

# %% [markdown]
# מאיפה אתה מתחיל

# %%
str = "0123456789ABCDEF"
print(str[:1:])
print(str[:2:])
print(str[:5:])
# Out:
# 0
# 01
# 01234

# %% [markdown]
# איפה זה מסיים

# %%
str = "0123456789ABCDEF"
print(str[::1])
print(str[::2])
print(str[::3])
# Out:
# 0123456789ABCDEF
# 02468ACE
# 0369CF

# %% [markdown]
# בקפיצות של כמה

# %%
str = "0123456789ABCDEF"
print(str[::-1])
print(str[len(str)::-1])
# Out:
# FEDCBA9876543210
# FEDCBA9876543210

# %% [markdown]
# הסוף וההתחלה ומה שגורם לשינוי הוא הקפיצות,שהם במספר נגדי (-1)

# %%
word = input("Enter word: ")
print(word)
print(word[::-1])
print(word == word[::-1])
# Out:
# קקה
# הקק
# False

# %% [markdown]
# כשהמספר הוא פלינדרום

# %%
str = "0123456789ABCDEF"
print(str[::2])
print(str[1::2])
print(str[5:10:1])
# Out:
# 02468ACE
# 13579BDF
# 56789

# %% [markdown]
# עשיתי

# %%
str = "0123456789ABCDEF"
print("1" in str)
print("12" in str)
print("ABC" in str)
print("135" in str)
# Out:
# True
# True
# True
# False

# %% [markdown]
# הוא בודק אם המספר קיים  במחרוזת

# %%
print("122333444455555".count("1"))
print("122333444455555".count("2"))
print("122333444455555".count("4"))
print("122333444455555".count("6"))
# Out:
# 1
# 2
# 4
# 0

# %% [markdown]
# הוא סופר כמה פעמים המספר נמצא במחרוזת

# %%
str = "0123456789ABCDEF"
print(str.find("0"))
print(str.find("01"))
print(str.find("789"))
print(str.find("EF"))
print(str.find("FE"))
# Out:
# 0
# 0
# 7
# 14
# -1

# %% [markdown]
# הוא מוצא את המיקום ואם הוא לא מצא אותו הוא מוציא -1

# %%
str = "0123456789ABCDEF"
print(str.startswith("0123"))
print(str.startswith("1234"))
# Out:
# True
# False

# %% [markdown]
# בודק אם המחרוזת מתחילה עם התת מחרוזת

# %%
str = "0123456789ABCDEF"
print(str.endswith("DEF"))
print(str.endswith("EFD"))
# Out:
# True
# False

# %% [markdown]
#  עשיתי

# %%
s1 = "Hello name!"
name = input("Enter your name: ")
s2 = s1.replace("name", name)
print(s2)
# Out:
# Hello kakashka!

# %% [markdown]
# הוא מחליף בתבנית את מה שהצבנו

# %%
print("1234".isnumeric())
print("1234".isalpha())
print("abcd".isnumeric())
print("abcd".isalpha())
# Out:
# True
# False
# False
# True

# %% [markdown]
# הוא בודק אם זה אותיות
# הוא בודק אם זה מספרים

# %%
print("-1234".isnumeric())
print("-1234".isalpha())
# Out:
# False
# False

# %% [markdown]
# כי הוא מחשיב שמינוס הוא לא מספר ולא אות

# %%
print("abcdef".upper())
print("ABCDEF".lower())
# Out:
# ABCDEF
# abcdef

# %% [markdown]
# את המחרוזת באותיות גדולות/קטנות

# %%
s1 = "One two THree"
s1=("One two THree".upper())
s2 = "one TWO three"
s2=("One two THree".upper())
print(s1 == s2)
print(s1 == s2)
# Out:
# True
# True

# %% [markdown]
# סיימתי!!!!!!
