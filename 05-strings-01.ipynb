# %%
str = "0123456789ABCDEF"
print(str[0])
print(str[1])
print(str[-1])
print(str[-2])
# Out:
# 0
# 1
# F
# E

# %% [markdown]
# מה העבדל בין גישה לאותיות מהתחלה ומהסוף (איפו האינדקס מתחיל בשני המקרים)?
# האינדקס בהצחלה מצחיל מ0 ומהסוף אין -0,אז מתחילים מ-1

# %%
str = "0123456789ABCDEF"
print(len(str))
# Out:
# 16

# %% [markdown]
# len - מה מחזירה פונקציה?
# חיבור של המחרוזת

# %%
str = "0123456789ABCDEF"
print(str[len(str)-1])
print(str[-1])
# Out:
# F
# F

# %% [markdown]
# למה זה מדפיס אותה אות?
# מכיוון שמתכוונים לאותו מיקום

# %%
name = input("Enter your name: ")
print("Hello " + name + "!")
# Out:
# Hello חזיר!

# %% [markdown]
# מה פעולה + עושה עם המחרוזות?הוא מחבר בין המחרוזת להדפסה הקבועה

# %%
21q ``21q   ```````name = input("Enter your name: ")
print("Hello "*2 + name*2)
# Out:
# Hello Hello צקם'צקם'

# %% [markdown]
# מה פעולה * עושה עם המחרוזות?המחרוזת חוזרת עך עצמה כפול 2

# %%
str = "0123456789ABCDEF"
print(str[0:len(str):1])
print(str[0::1])
print(str[0::])
print(str[::])
# Out:
# 0123456789ABCDEF
# 0123456789ABCDEF
# 0123456789ABCDEF
# 0123456789ABCDEF

# %% [markdown]
# איך זה שכל השורות מדפיסות אותו דבר?<br>
# מה המשמעות של ערכים דפולטיים (default)?
# היחס של המיקומים בכל השורות אומר להקריא את כל המחרוזת

# %%
str = "0123456789ABCDEF"
print(str[::])
# Out:
# 0123456789ABCDEF

# %% [markdown]
# מהם הערכים הדפולטיים במקרה הזה?
# הדפסת כל המחרוזת

# %%
str = "0123456789ABCDEF"
print(str[0::])
print(str[1::])
print(str[5::])
# Out:
# 0123456789ABCDEF
# 123456789ABCDEF
# 56789ABCDEF

# %% [markdown]
# מה המשמעות של מספר הראשון בתווך?
# מאיזה מיקום להתחיל להדפיס את המספרים

# %%
str = "0123456789ABCDEF"
print(str[:1:])
print(str[:2:])
print(str[:5:])
# Out:
# 0
# 01
# 01234

# %% [markdown]
# מה המשמעות של מספר השני בתווך?
#  להקריא את האיברים לפני מיקום האיבר הזה

# %%
str = "0123456789ABCDEF"
print(str[::1])
print(str[::2])
print(str[::3])
# Out:
# 0123456789ABCDEF
# 02468ACE
# 0369CF

# %% [markdown]
# מה המשמעות של מספר השלישי בתווך? להקריא רק את המיקומים המתחלקים במספר זה ש

# %%
str = "0123456789ABCDEF"
print(str[::-1])
print(str[len(str)::-1])
# Out:
# FEDCBA9876543210
# FEDCBA9876543210

# %% [markdown]
# מה הערכים הדפולטיים עכשיו?<br>
# מה לדעתך גורם להבדל?
# מתחילים מהמיקומים של הסוף,המחרוזת תראה הפוכה

# %%
word = input("Enter word: ")
print(word)
print(word[::-1])
print(word == word[::-1])
# Out:
# באזינגה
# הגניזאב
# False

# %% [markdown]
# true - מתי שורה שלישית מדפיסה?<br>
# מה זה אומר על המילה?
# השורה תדפיס TRUE רק כשהמיקומים מההתחלה ביחס למיקומים מהסוף יהיו זהים.צריך להכניב מילה פלינדרומית

# %%
str = "0123456789ABCDEF"
print(str[::2])
print(str[1::2])
print(str[5:10:])
# Out:
# 02468ACE
# 13579BDF
# 56789

# %% [markdown]
# תשלימו את הקוד כך שיודפס<br>
# 02468ACE<br>
# 13579BDF<br>
# 56789

# %%
str = "0123456789ABCDEF"
print("1" in str)
print("12" in str)
print("ABC" in str)
print("135" in str)
# Out:
# True
# True
# True
# False

# %% [markdown]
# in - מה האופרטור מחזיר?
# האם הירופים קיימים במחרוזת

# %%
print("122333444455555".count("1"))
print("122333444455555".count("2"))
print("122333444455555".count("4"))
print("122333444455555".count("6"))
# Out:
# 1
# 2
# 4
# 0

# %% [markdown]
# count - מה הפונקציה מחזירה?
# היא מוצאת כמה מספרים מאותו הסוג הספציפי קיימים בפונקציה

# %%
str = "0123456789ABCDEF"
print(str.find("0"))
print(str.find("01"))
print(str.find("789"))
print(str.find("EF"))
print(str.find("FE"))
# Out:
# 0
# 0
# 7
# 14
# -1

# %% [markdown]
# find - מה הפונקציה מחזירה?
# הוא מוצא מיקומים של צירופים

# %%
str = "0123456789ABCDEF"
print(str.startswith("0123"))
print(str.startswith("1234"))
# Out:
# True
# False

# %% [markdown]
# startswith - מה הפונקציה מחזירה?
# היאר בודקת האם המחרוזת מתחילה בצירוף המספרים הספציפי הזה

# %%
str = "0123456789ABCDEF"
print(str.endswith("CDEF"))
print(str.endswith("0123"))
# Out:
# True
# False

# %% [markdown]
# endswith - תשלימו את קוד כך שיודפס<br>
# true<br>
# false

# %%
s1 = "Hello name!"
name = input("Enter your name: ")
s2 = s1.replace("name", name)
print(s2)
# Out:
# Hello נןאבי!

# %% [markdown]
# replace - מה הפונקציה מחזירה?
# משתנה הבנוי משני משתנים

# %%
print("1234".isnumeric())
print("1234".isalpha())
print("abcd".isnumeric())
print("abcd".isalpha())
# Out:
# True
# False
# False
# True

# %% [markdown]
# isnumeric(), isalpha()<br>
# מה הפונקציות מחזירות?
# האם משהו מתחיל או מסתיים

# %%
 print("-1234".isnumeric())
print("-1234".isalpha())

# %% [markdown]
# false - למה שניהם החזירו?
# כי מינוס גורם למספר להריאות יחיד

# %%
print("abcdef".upper())
print("ABCDEF".lower())
# Out:
# ABCDEF
# abcdef

# %% [markdown]
# upper(), lower()<br>
# מה הפונקציות מחזירות?
# הן הופכות את האותיות לקטנות או גדולות באנגלית

# %%
s1 = "One TWO three"
s2 = "One TWO three"
print(s1 == s2)
print(s1 == s2)
# Out:
# True
# True

# %% [markdown]
# תשתמשו בפונקציות<br>
# upper() lower()<br>
# כך שיודפס<br>
# true<br>
# true
# work smarter not harder goshA
