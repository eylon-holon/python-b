# %%
str = "0123456789ABCDEF"
print(str[0])
print(str[1])
print(str[-1])
print(str[-2])

# %%
מה העבדל בין גישה לאותיות מהתחלה ומהסוף (איפו האינדקס מתחיל בשני המקרים)?
 -1-מהתחלה קוראים את המיקומים מ0 ומהסוף מ

# %%
str = "0123456789ABCDEF"
print(len(str))
# Out:
# 16

# %% [markdown]
# len - מה מחזירה פונקציה?
# את כל האורך של STR

# %%
str = "0123456789ABCDEF"
print(str[len(str)-1])
print(str[-1])
# Out:
# F
# F

# %% [markdown]
#  -1 כי זה אותו מיקום

# %%
name = input("Enter your name: ")
print("Hello " + name + "!")
# Out:
# Hello נועם!

# %% [markdown]
# מה פעולה + עושה עם המחרוזות?
# מחבר בין השם שניתן ל"HELLO" ול"!"

# %%
name = input("Enter your name: ")
print("Hello "*2 + name*2)
# Out:
# Hello Hello סאניסאני

# %% [markdown]
# מה פעולה * עושה עם המחרוזות?
# מכפיל את נתון כך שהוא נרשם פעמיים

# %%
str = "0123456789ABCDEF"
print(str[0:len(str):1])
print(str[0::1])
print(str[0::])
print(str[::])
print(str[:])
# Out:
# 0123456789ABCDEF
# 0123456789ABCDEF
# 0123456789ABCDEF
# 0123456789ABCDEF

# %% [markdown]
# איך זה שכל השורות מדפיסות אותו דבר?<br>
# מה המשמעות של ערכים דפולטיים (default)?
# כאשר לא רשום פייטון אוטומטית עושה את כל האורך של STR וכאשר לא רשום הצעד פייטון אוטומטית עושה צעד 1 וכאשר לא נתון מתי מתחיל הוא מתחיל מ0

# %%
str = "0123456789ABCDEF"
print(str[::])
# Out:
# 0123456789ABCDEF

# %% [markdown]
# מהם הערכים הדפולטיים במקרה הזה?
# 0:16:1

# %%
str = "0123456789ABCDEF"
print(str[0::])
print(str[1::])
print(str[5::])
# Out:
# 0123456789ABCDEF
# 123456789ABCDEF
# 56789ABCDEF

# %% [markdown]
# מה המשמעות של מספר הראשון בתווך?
# באיזה מיקום הוא מתחיל

# %%
str = "0123456789ABCDEF"
print(str[:1:])
print(str[:2:])
print(str[:5:])
# Out:
# 0
# 01
# 01234

# %% [markdown]
# מה המשמעות של מספר השני בתווך?
# האורך שהוא ידפיס מ STR

# %%
str = "0123456789ABCDEF"
print(str[::1])
print(str[::2])
print(str[::3])
# Out:
# 0123456789ABCDEF
# 02468ACE
# 0369CF

# %%
str = "0123456789ABCDEF"
print(str[:])
print(str[1:4])
print(str[4:])
print(str[:3])

# %% [markdown]
# מה המשמעות של מספר השלישי בתווך?
# מספר הצעדים

# %%
str = "0123456789ABCDEF"
print(str[::-1])
print(str[len(str)::-1])
# Out:
# FEDCBA9876543210
# FEDCBA9876543210

# %% [markdown]
# מה הערכים הדפולטיים עכשיו?<br>
# מה לדעתך גורם להבדל?
# 0:16:-1
#  מינןס 1 הבדל הוא שזה מודפס הפוך כי זה

# %%
word = input("Enter word: ")
print(word)
print(word[::-1])
print(word == word[::-1])
# Out:
# הזה
# הזה
# True

# %% [markdown]
# true - מתי שורה שלישית מדפיסה?<br>
# מה זה אומר על המילה?
#  כאשר זה פאלחנדרום

# %%
str = "0123456789ABCDEF"
print(str[::2])
print(str[1::3])
print(str[5:10:1])
# Out:
# 02468ACE
# 147AD
# 56789

# %% [markdown]
# תשלימו את הקוד כך שיודפס<br>
# 02468ACE<br>
# 13579BDF<br>
# 56789

# %%
str = "0123456789ABCDEF"
print("1" in str)
print("12" in str)
print("ABC" in str)
print("135" in str)
# Out:
# True
# True
# True
# False

# %% [markdown]
# in - מה האופרטור מחזיר?
# בודק אם התת מחרוזת נמצא במחרוזת STR

# %%
print("122333444455555".count("1"))
print("122333444455555".count("2"))
print("122333444455555".count("4"))
print("122333444455555".count("6"))
# Out:
# 1
# 2
# 4
# 0

# %% [markdown]
# cunt - מה הפונקציה מחזירה?
# מחזיר כמה פעמים רותו מספר מופיע במחרוזת

# %%
str = "0123456789ABCDEF"
print(str.find("0"))
print(str.find("01"))
print(str.find("789"))
print(str.find("EF"))
print(str.find("FE"))
# Out:
# 0
# 0
# 7
# 14
# -1

# %% [markdown]
# find - מה הפונקציה מחזירה?
# היא מחזירה איפה מתחילה התת מחרוזת על מחרוזת STR

# %%
str = "0123456789ABCDEF"
print(str.startswith("0123"))
print(str.startswith("1234"))
# Out:
# True
# False

# %% [markdown]
# מחזירה TRUE או FALSE אם המחרוזת מתחילה בתת מחרוזת

# %%
str = "0123456789ABCDEF"
print(str.endswith("DEF"))
print(str.endswith("יFFGי"))
# Out:
# True
# False

# %% [markdown]
# endswith - תשלימו את קוד כך שיודפס<br>
# true<br>
# false

# %%
s1 = "Hello name!"
name = input("Enter your name: ")
s2 = s1.replace("name", name)
print(s2)
# Out:
# Hello ירכי!

# %% [markdown]
# replace - מה הפונקציה מחזירה?
# מחזירה את המחרוזת עם השם מוחלף

# %%
print("1234".isnumeric())
print("1234".isalpha())
print("abcd".isnumeric())
print("abcd".isalpha())
# Out:
# True
# False
# False
# True

# %% [markdown]
# isnumeric(), isalpha()<br>
# מה הפונקציות מחזירות?
# אם זה מספר או לא ואם זה אות או לא

# %%
print("-1234".isnumeric())
print("-1234".isalpha())
# Out:
# False
# False

# %% [markdown]
# false - למה שניהם החזירו?
# כי זה מינוס

# %%
print("abcdef".upper())
print("ABCDEF".lower())
# Out:
# ABCDEF
# abcdef

# %% [markdown]
# upper(), lower()<br>
# מה הפונקציות מחזירות?
# את התת מחרוזת באותיות ההפוכות לה

# %%
s1 = "One two THree"
s2 = "one TWO three"
s1=("One two THree".upper())
s2=("One two THree".upper())
print(s1 == s2)
print(s1 == s2)
# Out:
# True
# True

# %% [markdown]
# תשתמשו בפונקציות<br>
# upper() lower()<br>
# כך שיודפס<br>
# true<br>
# true
