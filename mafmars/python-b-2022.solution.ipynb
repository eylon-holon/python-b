# %% [markdown]
# ## [🎦](https://www.youtube.com/playlist?list=PLNLf5_3sUeLyVVLPFQ-n31rPJQ_D49J8O)
# ![](./img/img_00550.png)

# %% [markdown]
# ## [🎦](https://youtu.be/fjVMP7eKtnw) <span style="color:magenta">שאלה 1</span>

# %% [markdown]
# ### לפניכם ארבעה קטעי קוד
# ### מה הערך שיודפס בכל אחד מהם

# %%
arr = [32, 51, 13, 23, 30]
arr.sort()
tmp = arr[-1]
print(tmp)

# %%
arr = [32, 51, 13, 23, 30]
tmp = arr[0]
for item in arr:
    if item > tmp:
        tmp = item
print(tmp)

# %%
arr = [32, 51, 13, 23, 30]
tmp = max(arr)
print(tmp)

# %%
arr = [32, 51, 13, 23, 30]
arr.sort(reverse = True)
tmp = arr[0]
print(tmp)

# %% [markdown]
# ## ![](https://youtu.be/OSejF_vh1WA) <span style="color:magenta">שאלה 2</span>

# %% [markdown]
# ![](img/img_00098.png)

# %%
list1 = ['Israel', 'Japan', 'Italy', 'Jordan', 'Israel', 'Portugal']
list1.remove('Israel')
print (list1)
print (len(list1))

# %%
list1 = ['Israel', 'Japan', 'Italy', 'Jordan', 'Israel', 'Portugal']
for i in range(len(list1)):
    if 'Israel' in list1:
        list1.remove('Israel')
print (list1)
print (len(list1))

# %%
list1 = ['Israel', 'Japan', 'Italy', 'Jordan', 'Israel', 'Portugal']
count1 = list1.count('Israel')
for i in range(count1):
    list1.remove('Israel')
print (list1)
print (len(list1))

# %%
list1 = ['Israel', 'Japan', 'Italy', 'Jordan', 'Israel', 'Portugal']
count = list1.index('Israel')
list1 = list1[count+1:]
print (list1)
print (len(list1))

# %%
list1 = ['Israel', 'Japan', 'Italy', 'Jordan', 'Israel', 'Portugal']
list2 = []
for state in list1:
    if not state == 'Israel':
        list2.append(state)
list1 = list2
print (list1)
print (len(list1))

# %% [markdown]
# ## ![](https://youtu.be/CoWxp2lC3zc) <span style="color:magenta">שאלה 3</span>

# %% [markdown]
# ![](img/img_00099.png)

# %% [markdown]
# ![](img/img_00100.png)

# %%
min = 10
#num = int(input("enter 4 digit number"))
num = 9257
for i in range(4):
    tmp = num % 10
    if min > tmp:
        min = tmp
    num = num // 10
print(min)

# %% [markdown]
# 1 - מינימום צרילך להיות גדול בהתחלה
# 3 - מיותר
# 4.1 - tmp = ...
# 4.3 - num = num // 10
# 5 - print(min)

# %% [markdown]
# ## ![](https://youtu.be/e25khOX0HRU) <span style="color:magenta">שאלה 4</span>

# %% [markdown]
# ![](img/img_00101.png)

# %%
def f1(lst):
    for x in lst:
        if x < 0:
            print(x)
            
lst = [-7,2,10,5,-2,8,-1,0]
f1(lst)

# %% [markdown]
# לא
# -7
# -2
# -1

# %%
def f2(lst):
    for x in lst[::-1]:
        if x < 0:
            print(x)
            
lst = [-7,2,10,5,-2,8,-1,0]
f2(lst)

# %% [markdown]
# כן
# -1
# -2
# -7

# %%
def f3(lst):
    for i in range(len(lst)-1,-1,-1):
        if lst[i] < 0:
            print(lst[i])
            
lst = [-7,2,10,5,-2,8,-1,0]
f3(lst)

# %% [markdown]
# כן
# -1
# -2
# -7

# %%
def f4(lst):
    for i in range(len(lst)):
        if lst[i] < 0:
            print(i)
            
lst = [-7,2,10,5,-2,8,-1,0]
f4(lst)

# %% [markdown]
# לא
# -7
# -2
# -1

# %% [markdown]
# ## ![](https://youtu.be/a4MK7uoe7DM) <span style="color:magenta">שאלה 5</span>

# %% [markdown]
# ### בכל אחד מקטעי הקוד הבאים, יש לסמן מה יודפס בסיומו

# %%
import queue
q1 = queue.Queue()
q2 = queue.Queue()
q1.put(10)
q1.put(20)
q1.put(30)
q1.put(40)
while not q1.empty():
    q2.put(q1.get())
while not q2.empty():
    q1.put(q2.get())
x = q1.get()
print(x)
# Out:
# 10

# %%
import queue
q1 = queue.Queue()
list1 = []
q1.put(10)
q1.put(20)
q1.put(30)
q1.put(40)
while not q1.empty():
    list1.append(q1.get())
for item in list1:
    q1.put(item)
x = q1.get()
print(x)

# %%
import queue
q1 = queue.Queue()
q1.put(10)
q1.put(20)
q1.put(30)
q1.put(40)
l = []
s = 0
while not q1.empty():
    x = q1.get()
    l.append(x)
    s = s + x
print(s)

# %%
import queue
q1 = queue.Queue()
list1 = []
q1.put(10)
q1.put(20)
q1.put(30)
q1.put(40)
temp = q1.get() + q1.get()
q1.put(temp)
temp = q1.get() + q1.get()
q1.put(temp)
print(q1.get())

# %% [markdown]
# ## ![](https://youtu.be/1UqHXTYvHxU) <span style="color:magenta">שאלה 6</span>

# %% [markdown]
# ![](img/img_00103.png)

# %%
def _________(password):
    temp = password[0]._______()
    temp = temp + password[1: ]
    temp = temp._______('a', ___)
    temp = temp.replace('i', ___)
    print (________)

# %%
def change_password(password):
    temp = password[0].upper()
    temp = temp + password[1: ]
    temp = temp.replace('a', '@')
    temp = temp.replace('i','1')
    print (temp)

change_password("telaviv")
change_password("mazaltov")

# %% [markdown]
# ## [🎦](https://youtu.be/8JFAjMsVNX8) <span style="color:magenta">שאלה 7</span>

# %% [markdown]
# ![](img/img_00104.png)

# %%
def is_exist(lst, tav):
    for item in ________ :
    if tav not in ______:
        print (________)
    print (_______)

# %%
def is_exist(lst, tav):
    for item in lst:
        if tav not in item:
            print("OUT")
            return
    print ("IN")

# %% [markdown]
# ![](img/img_00105.png)

# %%
def is_exist(lst, tav):
    for item in ________ :
    if tav not in ______:
        print (________)
    print (_______)

# %%
def is_exist(lst, tav):
    for item in lst:
        if tav in item:
            print ("IN")
            return
    print ("OUT")

# %% [markdown]
# ## ![](https://youtu.be/Usv9auBSEX0) <span style="color:magenta">שאלה 8</span>

# %% [markdown]
# ![](img/img_00106.png)

# %% [markdown]
# ![](img/img_00107.png)

# %%
def select(lst1, party_time):
    lst1_size = len(_____)
    return_lst = []
    sum_time = ______
    for item in lst1:
        if (sum_time + ______) < (party_time * ___):
            _______.append(_____)
            sum_time = sum_time + item
print(_________)

lst1 = [120, 150, 200, 300, 190, 170, 250, 210, 230]
select(lst1, 10)

# %%
def select(lst1, party_time):
    lst1_size = len(lst1)
    return_lst = []
    sum_time = 0
    for item in lst1:
        if (sum_time + item) < (party_time * 60):
            return_lst.append(item)
            sum_time = sum_time + item
    print(return_lst)

select([190, 150, 240, 220, 270], 10)
select([120, 150, 200, 300, 190, 170, 250, 210, 230], 10)

# %% [markdown]
# ![](img/img_00108.png)

# %% [markdown]
# ![](img/img_00109.png)

# %%
def shuffle(lst1):
    import random
    lst_size = len(lst1)
    shift_size = int(_______ * 0.25)
    for i in range (______):
        random_index = random.randrange(0,_____)
        item = lst1._____(random_index)
        lst1._____(_____)
    print (______)

lst1 = [120, 150, 200, 300, 190, 170, 250, 210, 230]
shuffle(lst1)

# %%
def shuffle(lst1):
    import random
    lst_size = len(lst1)
    shift_size = int(lst_size * 0.25)
    for i in range (shift_size):
        random_index = random.randrange(0,lst_size)
        item = lst1.pop(random_index)
        lst1.append(item)
    print(lst1)

lst1 = [120, 150, 200, 300, 190, 170, 250, 210, 230]
shuffle(lst1)
