# %% [markdown]
# ### <span style="color:magenta">שאלה 1</span>

# %% [markdown]
# ### לפניכם ארבעה קטעי קוד
# ### מה הערך שיודפס בכל אחד מהם

# %% [markdown]
# ```py
# arr = [32, 51, 13, 23, 30]
# arr.sort()
# tmp = arr[-1]
# print(tmp)
# ```

# %% [markdown]
# 51

# %% [markdown]
# ```py
# arr = [32, 51, 13, 23, 30]
# tmp = arr[0]
# for item in arr:
#     if item > tmp:
#         tmp = item
# print(tmp)
# ```

# %% [markdown]
# 51

# %% [markdown]
# ```py
# arr = [32, 51, 13, 23, 30]
# tmp = max(arr)
# print(tmp)
# ```

# %% [markdown]
# 51

# %% [markdown]
# ```py
# arr = [32, 51, 13, 23, 30]
# arr.sort(reverse = True)
# tmp = arr[0]
# print(tmp)
# ```

# %% [markdown]
# 51

# %% [markdown]
# ### <span style="color:magenta">שאלה 2</span>

# %% [markdown]
# ![](img/img_00098.png)

# %% [markdown]
# ```py
# list1 = [‘Israel’, ‘Japan’, ‘Italy’, ‘Jordan’, ‘Israel’, ‘Portugal’]
# list1.remove(‘Israel’)
# print (list1)
# print (len(list1))
# ```

# %% [markdown]
# Japan’, ‘Italy’, ‘Jordan’, ‘Portugal’
# 4

# %% [markdown]
# ```py
# list1 = [‘Israel’, ‘Japan’, ‘Italy’, ‘Jordan’, ‘Israel’, ‘Portugal’]
# for i in range(len(list1)):
#     if ‘Israel’ in list1:
#         list1.remove(‘Israel’)
# print (list1)
# print (len(list1))
# ```

# %% [markdown]
# japan,italy,jorden,portugal
# 4

# %% [markdown]
# ```py
# list1 = [‘Israel’, ‘Japan’, ‘Italy’, ‘Jordan’, ‘Israel’, ‘Portugal’]
# count1 = list1.count(‘Israel’)
# for i in range(count1):
#     list1.remove(‘Israel’)
# print (list1)
# print (len(list1))
# ```

# %% [markdown]
# japan,italy,jorden,portugal
# 4

# %% [markdown]
# ```py
# list1 = [‘Israel’, ‘Japan’, ‘Italy’, ‘Jordan’, ‘Israel’, ‘Portugal’]
# count = list1.index(‘Israel’)
# list1 = list1[count+1:]
# print (list1)
# print (len(list1))
# ```

# %% [markdown]
# japan,italy,jorden,isreal,portugal
# 5

# %% [markdown]
# ```py
# list1 = [‘Israel’, ‘Japan’, ‘Italy’, ‘Jordan’, ‘Israel’, ‘Portugal’]
# list2 = []
# for state in list1:
#     if not state == ‘Israel’:
#         list2.append(state)
# list1 = list2
# print (list1)
# print (len(list1))
# ```

# %% [markdown]
# japan,italy,jorden,portugal
# 4

# %% [markdown]
# ### <span style="color:magenta">שאלה 3</span>

# %% [markdown]
# ![](img/img_00099.png)

# %% [markdown]
# ![](img/img_00100.png)

# %% [markdown]
# | הצעת תיקון  | מה השגיאה  |     מספר שורה  |   |
# |---            |---            |---        |---|
# |       1       | THE MIN IS TOO SMALL  | MIN=10   | 1 |
# |               |               |           | 2 |
# |               |               |           | 3 |

# %% [markdown]
# ### <span style="color:magenta">שאלה 4</span>

# %% [markdown]
# ![](img/img_00101.png)

# %% [markdown]
# ```py
# def f1(lst):
#     for x in lst:
#         if x < 0:
#             print(x)
#
# lst = [-7,2,10,5,-2,8,-1,0]
# f1(lst)
# ```

# %% [markdown]
# NO

# %% [markdown]
# ```py
# def f2(lst):
#     for x in lst[::-1]:
#         if x < 0:
#             print(x)
#
# lst = [-7,2,10,5,-2,8,-1,0]
# f2(lst)
# ```

# %% [markdown]
# YES

# %% [markdown]
# ```py
# def f3(lst):
#     for i in range(len(lst)-1,-1,-1):
#         if lst[i] < 0:
#             print(lst[i])
#
# lst = [-7,2,10,5,-2,8,-1,0]
# f3(lst)
# ```

# %% [markdown]
# YES

# %% [markdown]
# ```py
# def f4(lst):
#     for i in range(len(lst)):
#         if lst[i] < 0:
#             print(i)
#
# lst = [-7,2,10,5,-2,8,-1,0]
# f4(lst)
# ```

# %% [markdown]
# NO

# %% [markdown]
# ### <span style="color:magenta">שאלה 5</span>

# %% [markdown]
# ### בכל אחד מקטעי הקוד הבאים, יש לסמן מה יודפס בסיומו

# %% [markdown]
# ```py
# import queue
# q1 = queue.Queue()
# q2 = queue.Queue()
# q1.put(10)
# q1.put(20)
# q1.put(30)
# q1.put(40)
# while not q1.empty():
#     q2.put(q1.get())
# while not q2.empty():
#     q1.put(q2.get())
# x = q1.get()
# print(x)
# ```

# %% [markdown]
# ```py
# import queue
# q1 = queue.Queue()
# list1 = []
# q1.put(10)
# q1.put(20)
# q1.put(30)
# q1.put(40)
# while not q1.empty():
#     list1.append(q1.get())
# for item in list1:
#     q1.put(item)
# x = q1.get()
# print(x)
# ```

# %% [markdown]
# ???

# %% [markdown]
# ```py
# import queue
# q1 = queue.Queue()
# q1.put(10)
# q1.put(20)
# q1.put(30)
# q1.put(40)
# l = []
# s = 0
# while not q1.empty():
#     x = q1.get()
#     l.append(x)
#     s = s + x
# print(s)
# ```

# %% [markdown]
# ???

# %% [markdown]
# ```py
# import queue
# q1 = queue.Queue()
# list1 = []
# q1.put(10)
# q1.put(20)
# q1.put(30)
# q1.put(40)
# temp = q1.get() + q1.get()
# q1.put(temp)
# temp = q1.get() + q1.get()
# q1.put(temp)
# print(q1.get())
# ```

# %% [markdown]
# ???

# %% [markdown]
# ### <span style="color:magenta">שאלה 6</span>

# %% [markdown]
# ![](img/img_00103.png)

# %%
def passward(password):
    temp = password[0].upper()
    temp = temp + password[1:  ]
    temp = temp.replace('a', _@__)
    temp = temp.replace('i', __1_)
    print(temp)

change_password("telaviv")
change_password("mazaltov")

# %% [markdown]
# ### <span style="color:magenta">שאלה 7</span>

# %% [markdown]
# ![](img/img_00104.png)

# %%
def is_exist(lst, tav):
    for item in ist :
    if tav not in item:
        print (out)
        return
    print (_in_)

# %% [markdown]
# ![](img/img_00105.png)

# %%
def is_exist(lst, tav):
    for item in ____ist____ :
    if tav not in _item_____:
        print (____in____)
        return
    print (_____out__)

# %% [markdown]
# ### <span style="color:magenta">שאלה 8</span>

# %% [markdown]
# ![](img/img_00106.png)

# %% [markdown]
# ![](img/img_00107.png)

# %%
def select(lst1, party_time):
    lst1_size = len(ist1)
    return_lst = []
    sum_time = 0_
    for item in lst1:
        if (sum_time + __item____) < (party_time * __60_):
            _return_ist_.append(_item_)
            sum_time = sum_time + item
print(_return_ist_)

lst1 = [120, 150, 200, 300, 190, 170, 250, 210, 230]
select(lst1, 10)

# %% [markdown]
# ![](img/img_00108.png)

# %% [markdown]
# ![](img/img_00109.png)

# %%
def shuffle(lst1):
    import random
    lst_size = len(lst1)
    shift_size = int(_ist_size_ * 0.25)
    for i in range (_shift_size):
        random_index = random.randrange(0,ist_size_)
        item = lst1._pop_(random_index)
        lst1.append_(_random_index)
    print (_ist1_)

lst1 = [120, 150, 200, 300, 190, 170, 250, 210, 230]
shuffle(lst1)
