# %%
my = [["Dog",5], ["Cat",3], ["Bird",2], ["Rabbit",1], ["Turtle",8]]

print(len(my))
print(my[1][0])
print(my[0][1])
print(my[3])

s = 0
for item in my:
    s = s + item[1]
print(s)

x = 0
for item in my:
    if x < item[1]:
        x = item[1]
print(x)

x = ''
for item in my:
    x = x + item[0][0]
print(x)
# Out:
# 5
# Cat
# 5
# ['Rabbit', 1]
# 19
# 8
# DCBRT

# %%
num1 = 0
num2 = 5
if (num1>0 and num2//num1 == 0) or num2//3 == 0:
    print('Yes')
else:
    print('No')
# Out:
# No
