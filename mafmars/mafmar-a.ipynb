# %% [markdown]
# ### <span style="color:magenta">שאלה 1</span>

# %% [markdown]
# <img src="img/img_00002.png" width="800">

# %% [markdown]
# ```py
# num1 = 2
# num2 = num1 + 5
# num1 = num1 + num2 + 3
# print("num1 = ", num1, "num2 = ", num2)
# ```

# %% [markdown]
# num1=12, num2=7

# %% [markdown]
# ```py
# num = 3
# num = 10
# num = num + 3
# print("num = ", num)
#
# ```

# %% [markdown]
# num=13

# %% [markdown]
# ```py
# str = "Yes We Can!!!"
# print(str[4])
# print(len(str))
# print(str[-3])
# print(str[::2])
# print(str[4:-3])
# print(str[:])
# ```

# %% [markdown]
# W
# 13
# !
# YsW aN!
# We Can
# Yes We Can!!!

# %%
str = "Yes We Can!!!"
print(str[4])
print(str[4:-3])
print(str[:])
# Out:
# W
# We Can
# Yes We Can!!!

# %% [markdown]
# ### <span style="color:magenta">שאלה 2</span>

# %% [markdown]
# <img src="img/img_00001.png" width="850">

# %% [markdown]
# ```py
# num1 = int(input("Enter first number"))
# num2 = int(input("Enter second number"))
# if num1 > 5 and num2 <= 4:
#     print("Yes")
# else:
#     print("No")
# ```

# %% [markdown]
# |       |Yes    | No |
# |--     |---    |--- |
# |num1   |   10    |  4  |
# |num2   |   3    |  10  |

# %% [markdown]
# ```py
# num1 = int(input("Enter first number"))
# num2 = int(input("Enter second number"))
# if num1 > 5 or num2 <= 4:
#     print("Yes")
# else:
#     print("No")
# ```

# %% [markdown]
# |       |Yes    | No |
# |--     |---    |--- |
# |num1   |    20   | 4   |
# |num2   |     10  |   1 |

# %% [markdown]
# ```py
# num1 = int(input("Enter first number"))
# num2 = int(input("Enter second number"))
# if (num1 > 5 or num2 <= 4) and num1 == num2:
#     print("Yes")
# else:
#     print("No")
# ```

# %% [markdown]
# |       |Yes    | No |
# |--     |---    |--- |
# |num1   |     10  |  2  |
# |num2   |     10 |   1 |

# %% [markdown]
# ```py
# num1 = int(input("Enter first number"))
# num2 = int(input("Enter second number"))
# if num1 > 5 or (num2 <= 4 and num1 == num2):
#     print("Yes")
# else:
#     print("No")
# ```

# %% [markdown]
# |       |Yes    | No |
# |--     |---    |--- |
# |num1   |6 |   1 |
# |num2   |  4     |  4  |

# %% [markdown]
# ### <span style="color:magenta">שאלה 3</span>

# %% [markdown]
# <img src="img/img_00002.png" width="800">

# %% [markdown]
# ```py
# for k in range(10):
#     if k % 2 == 0:
#         print(k + 1)
# ```

# %% [markdown]
# 3
# 5
# 7
# 9

# %% [markdown]
# ```py
# for k in range(20):
#     if k % 3 == 0 and k <= 9:
#         print(k)
# ```

# %% [markdown]
# 9
# 12
# 15
# 18

# %% [markdown]
# ```py
# for k in range(3, 10, 2):
#     print(k)
# ```

# %% [markdown]
# 3
#
# 5
#
# 7
#
# 9

# %% [markdown]
# ```py
# for k in range(40, 0, -10):
#     print(k)
# ```

# %% [markdown]
# 40
# 30
# 20
# 10

# %% [markdown]
# ### <span style="color:magenta">שאלה 4</span>

# %% [markdown]
# <img src="img/img_00002.png" width="800">

# %% [markdown]
# ```py
# num = 123
# print(num // 100)
# print(num // 10 % 10)
# print(num % 10)
# ```

# %% [markdown]
# 23
#
# 0
#
# 3

# %% [markdown]
# ```py
# num = 12345
# print(num // 100)
# print(num % 100)
# ```

# %% [markdown]
# 123
#
# 43

# %% [markdown]
# ```py
# num = 12345
# print(num // 100 // 10)
# print(num // 10 % 10)
# ```

# %% [markdown]
# 3
#
# 4

# %% [markdown]
# ```py
# num = 123
# while (num > 0):
#     print(num % 10)
#     num = int(num // 10)
# ```

# %% [markdown]
# 3
#
# 2
#
# 1

# %% [markdown]
# ### <span style="color:magenta">שאלה 5</span>

# %% [markdown]
# <img src="img/img_00003.png" width="900">

# %%
def num_even():
    count = 0
    index = 0
    num = int(input("Enter a number: "))
    while index > 10:
        if num <= 99 and num >= 10:
            count = count + 1
        index = index + 1
        num = int(input("Enter a number: "))
    print("count", count)

# %% [markdown]
#  הטעות היא בכך שאין קלט בתוך המחרוזת

# %%
def num_even():
    count = 0
    index = 0
    while index < 10:
        num = int(input("Enter a number: "))
        if num <= 99 and num >= 10:
            count=count+1
        index = index + 1
    print('count',count)

# %% [markdown]
#  אנחנו מפספסים הוספה של אחד למשתנה ובנוסף המיקום של אחת הפקודות אינו נכון

# %%
def num_even():
    count = 0
    index = 0
    while index < 10:
        num = int(input("Enter a number: "))
        if num <= 99 and num >= 10:
            count = count + 1
        index = index + 1
    print("count", count)

# %% [markdown]
# הקלט צריך להיות מחוץ לאיף

# %% [markdown]
# ### <span style="color:magenta">שאלה 6</span>

# %% [markdown]
# ```py
# import jturtle
# t = jturtle.Turtle()
# t.shape("turtle")
# size = 100
# t.pendown()
# for index in range(4):
#     for item in range(4):
#         t.forward(size)
#         t.left(90)
#     size = size - 20
# ```

# %% [markdown]
# ב

# %% [markdown]
# איזה מבין הפלטים שלפניך יוצג על–גבי מסך המחשב?
# <img src="img/img_00004.png" width="800">

# %% [markdown]
# ### <span style="color:magenta">שאלה 7</span>

# %% [markdown]
# <img src="img/img_00005.png" width="900">

# %% [markdown]
# מה יהיה האיבר הבא בסדרה שבדוגמה

# %% [markdown]
# 34

# %% [markdown]
# לפניך קטע קוד שמדפיס את 8 האיברים הראשונים בסדרה. השלם את הקטע.

# %%
first = 1
second = 1
counter = 3
print("Fibonacci item 1 is ", first)
print("Fibonacci item 2 is ", second)
while counter <= 8:
    third = first + second
    first = second
    second = third
    print("Fibonacci item", counter, "is ", third)
    counter = counter + 1

# %% [markdown]
# ### <span style="color:magenta">שאלה 8</span>

# %% [markdown]
# <img src="img/img_00006.png" width="900">

# %%
def Exs8():
    counter = 0
    for k in range(1,301,1):
        gradeA = int(input("Enter grade A: "))
        gradeB = int(input("Enter grade B: "))
        if gradeB >= gradeA:
            counter = counter + 1
    if counter > 200:
        print("התוכנית מוצלחת")
    else:
        print("יש ליעל את התוכנית")
