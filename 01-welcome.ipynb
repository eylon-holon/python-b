# %% [markdown]
# תתחילו עבודה בלהריץ את המשבצת הבא

# %%
from eylon.core import *
start({
    "hello()": [
        [[], [], ['Gosha'], ['Hi Gosha']]
    ],
    "min()": [
        [[10, 20], [10], [], []],
        [[20, 10], [10], [], []],
        [[-10, -20], [-20], [], []],
    ],
    "max()": [
        [[10, 20], [20], [], []],
        [[20, 10], [20], [], []],
        [[-10, -20], [-10], [], []],
    ],
})
# Out:
# Hi segev-gordin 😁! Let's start the lesson... 🙌

# %% [markdown]
# עכשיו מימשו את הפונקציה
# אחרי כל שינוי בהגדרה של הפונקציה צריך להריץ את המשבצת
# זה מין כפתור שמור

# %%
def hello():
    name = input("Enter name: ")
    print("Hi " + name)

# %% [markdown]
# תריצו את הפונקציה
# hello()

# %% [markdown]
# סיימו את העבודה בהגשה של הפונקציה

# %%
hello(2
# Out:
#   Cell In[13], line 1
#     hello(2
#            ^
# SyntaxError: incomplete input

# %% [markdown]
# עכשיו הגישו את העבודה לבדיקה

# %%
submit(hello)
# Out:
# Hi Gosha
# Congrats segev-gordin! Got it: '01-welcome.hello'. Gosha is happy :) 👍

# %% [markdown]
# ממשו פונקציה
# min of two variables

# %%
def min(a, b):
    return a if a < b else b

def max(a, b):
    return a if a > b else b

# %% [markdown]
# בידקו את הפונקציה

# %%
print(min(10, 20))
print(min(20, 10))
print(min(-10, 20))
print(min(10, -20))
# Out:
# 10
# 10
# -10
# -20

# %% [markdown]
# הגישו את הפונקציה

# %%
submit(min)
# Out:
# Congrats segev-gordin! Got it: '01-welcome.min'. Gosha is happy :) 👍

# %% [markdown]
# עכשיו תממשו תבדקו והגישו פונקציה
# max of two variables
