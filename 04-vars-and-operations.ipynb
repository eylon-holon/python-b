# %% [markdown]
# הראשון מחבר אותם לדוגמה 1+2=12 והשני מחשב אותם, לדוגמה 1+2=3 לפי מתמטיקה---
# מה העבדל בין שני קטעי קוד

# %%
n1 = input("Enter number one")
n2 = inp

lut("Enter number two")
print(n1 + n2)
# Out:
# 12

# %%
n1 = int(input("Enter number one"))
n2 = int(input("Enter number two"))
print(n1 + n2)
# Out:
# 3

# %% [markdown]
# ---
# מה קוד הבא עושה?

# %%
def plus(a, b):
    return a + b

x = plus(10, 20)
print(x)
# Out:
# 30

# %% [markdown]
# ---
# מה קוד הבא אמור לעושה?

# %%
def do_math(a, math, b):
    if math == "+": return a + b
    if math == "-": return a - b
    if math == "*": return a * b
    if math == "/": return a / b
    if math == "%": return a % b
    if math == "//": return a // b
    return "I dont know what it is: " + math

# %%
print(do_math(10, "+", 20))
print(do_math(10, "-", 20))
print(do_math(10, "*", 20))
print(do_math(10, "/", 20))
# Out:
# 30
# -10
# 200
# 0.5

# %% [markdown]
# למה קוד הבא לא עובד?
# <br>
# הוסיפו שורות קוד בפונקציה
# <br>
# do_math()
# <br>
# כך שזה כן יעבוד
# <br>
# מה זה עושה?

# %%
print(do_math(22, "//", 3))
print(do_math(22, "%", 3))
print(do_math(22, "-", 10))
# Out:
# 7
# 1
# 12

# %% [markdown]
# תריצו את קוד הבא. האם זה עושה משמצפים?
# <br>
# תקנו טעעיות בקוד

# %%
a = input("Enter first number")
math = input("Enter math operator")
b = input("Enter second number")

print(do_math(a, math, b))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 5
#       2 math = input("Enter math operator")
#       3 b = input("Enter second number")
# ----> 5 print(do_math(a, math, b))
#
# Cell In[8], line 3, in do_math(a, math, b)
#       1 def do_math(a, math, b):
#       2     if math == "+": return a + b
# ----> 3     if math == "-": return a - b
#       4     if math == "*": return a * b
#       5     if math == "/": return a / b
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %% [markdown]
# ---
# מה קוד הבא עושה?
# <br>
# איך הוא עושה את זה?

# %%
def printDigits(num):
    while (num > 0):
        print(num % 10)
        num = num // 10

# %%
printDigits(12345)
# Out:
# 5
# 4
# 3
# 2
# 1

# %% [markdown]
# ---
# מה קוד הבא עושה?
# <br>
# איך הוא עושה את זה?

# %%
def secret(num):
    sod = 0
    while (num > 0):
        sod = sod + num % 10
        num = num // 10
    return sod

# %%
print(secret(123456789))
# Out:
# 45

# %%
print(secret(123456789))
print(secret(secret(123456789)))
print(secret(secret(secret(123456789))))
# Out:
# 45
# 9
# 9
