# %% [markdown]
# ההבדל הוא שהקטע הראשון לא מחבר בין שני המספרים והשני כן מחבר בינהם.
# מה העבדל בין שני קטעי קוד

# %%
n1 = input("Enter number one")
n2 = input("Enter number two")
print(n1 + n2)
# Out:
# 1020

# %%
n1 = int(input("Enter number one"))
n2 = int(input("Enter number two"))
print(n1 + n2)
# Out:
# 30

# %% [markdown]
# עוצר את הפקודה ומחשב ---
# מה קוד הבא עושה?

# %%
def plus(a, b):
    return a + b

x = plus(10, 20)
print(x)
# Out:
# 30

# %% [markdown]
#  מחשב לפי הסימן---
# מה קוד הבא אמור לעושה?

# %%
def do_math(a, math, b):
    if math == "+": return a + b
    if math == "-": return a - b
    if math == "*": return a * b
    if math == "/": return a / b
    return "I don't know what is: " + math

# %%
print(do_math(10, "+", 20))
print(do_math(10, "+", 20))
print(do_math(10, "*", 20))
print(do_math(10, "/", 20))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(do_math(10, "+", 20))
#       2 print(do_math(10, "+", 20))
#       3 print(do_math(10, "*", 20))
#
# NameError: name 'do_math' is not defined

# %% [markdown]
# למה קוד הבא לא עובד?
# <br>
# הוסיפו שורות קוד בפונקציה
# <br>
# do_math()
# <br>
# כך שזה כן יעבוד
# <br>
# מה זה עושה?

# %%
print(do_math(22, "//", 3))
print(do_math(22, "%", 3))
# Out:
# I don't know what is: //
# I don't know what is: %

# %% [markdown]
# תריצו את קוד הבא. האם זה עושה משמצפים?
# <br>
# תקנו טעעיות בקוד

# %%
a = input("Enter first number")
math = input("Enter math operator")
b = input("Enter second number")

print(do_math(a, math, b))
# Out:
# I don't know what is: 100

# %% [markdown]
# ---
# מה קוד הבא עושה?
# <br>
# איך הוא עושה את זה?

# %%
def printDigits(num):
    while (num > 0):
        print(num % 10)
        num = num // 10

# %%
printDigits(12345)
# Out:
# 5
# 4
# 3
# 2
# 1

# %% [markdown]
# ---
# מה קוד הבא עושה?
# <br>
# איך הוא עושה את זה?

# %%
def secret(num):
    sod = 0
    while (num > 0):
        sod = sod + num % 10
        num = num // 10
    return sod

# %%
print(secret(123456789))
# Out:
# 45

# %%
input(butifull is butifull)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 input(butifull is butifull)
#
# NameError: name 'butifull' is not defined

# %%
print(secret(123456789))
print(secret(secret(123456789)))
print(secret(secret(secret(123456789))))
# Out:
# 45
# 9
# 9
