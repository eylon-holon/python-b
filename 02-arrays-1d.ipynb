# %%
from eylon.core import *

start({
    "min()": [], 
    "max()": [], 
    "find()": [], 
    "findLast()": [], 
    "isPalidrome()": [], 
    "startsWith()": [], 
    "endsWith()": []
})
# Out:
# Hi segev-gordin 😁! Let's start the lesson... 🙌

# %% [markdown]
# === M I N ===

# %%
# return minimal value of an array
def min(a):
    m = a[0]
    for n in a:
        if n < m:
            m = n
    return m

# %%
print(min([1, 2, 3]))
print(min([1, 2, -3]))
print(min([-1, -20, -3]))
# Out:
# 1
# -3
# -20

# %%
submit(min)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 submit(min)
#
# File /workspaces/python-b/eylon/core.py:115, in submit(func)
#     112     return
#     114 log = json.dumps(lines, indent=2)
# --> 115 msg = post_results(func.__name__, src, log)
#     116 print(msg)
#
# File /workspaces/python-b/eylon/core.py:78, in post_results(fname, src, log)
#      67 api = "https://script.google.com/macros/s/AKfycbyLLStYfln3HEJdRNq_-xzc1ZAx8QD0TLFd9rSqVbv05zd2jK5WSg0uAo5NvtzLFQC2tw/exec"
#      68 request = {
#      69     'now': datetime.datetime.now().isoformat(),
#      70     'docId': cfg.docId,
#    (...)
#      76     'tags': ' '.join(cfg.tags)
#      77 }
# ---> 78 response = post(api, request)
#      79 return response["msg"]
#
# File /workspaces/python-b/eylon/post.py:8, in post(url, data)
#       6 request = Request(url, payload.encode())
#       7 with urlopen(request) as response:
# ----> 8     data = response.read().decode()
#       9     return json.loads(data)
#
# File /usr/local/python/3.12.1/lib/python3.12/http/client.py:473, in HTTPResponse.read(self, amt)
#     470     return b""
#     472 if self.chunked:
# --> 473     return self._read_chunked(amt)
#     475 if amt is not None:
#     476     if self.length is not None and amt > self.length:
#     477         # clip the read to the "end of response"
#
# File /usr/local/python/3.12.1/lib/python3.12/http/client.py:595, in HTTPResponse._read_chunked(self, amt)
#     593 value = []
#     594 try:
# --> 595     while (chunk_left := self._get_chunk_left()) is not None:
#     596         if amt is not None and amt <= chunk_left:
#     597             value.append(self._safe_read(amt))
#
# File /usr/local/python/3.12.1/lib/python3.12/http/client.py:579, in HTTPResponse._get_chunk_left(self)
#     577     self._safe_read(2)  # toss the CRLF at the end of the chunk
#     578 try:
# --> 579     chunk_left = self._read_next_chunk_size()
#     580 except ValueError:
#     581     raise IncompleteRead(b'')
#
# File /usr/local/python/3.12.1/lib/python3.12/http/client.py:539, in HTTPResponse._read_next_chunk_size(self)
#     537 def _read_next_chunk_size(self):
#     538     # Read the next chunk size from the file
# --> 539     line = self.fp.readline(_MAXLINE + 1)
#     540     if len(line) > _MAXLINE:
#     541         raise LineTooLong("chunk size")
#
# File /usr/local/python/3.12.1/lib/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File /usr/local/python/3.12.1/lib/python3.12/ssl.py:1253, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1249     if flags != 0:
#    1250         raise ValueError(
#    1251           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1252           self.__class__)
# -> 1253     return self.read(nbytes, buffer)
#    1254 else:
#    1255     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/local/python/3.12.1/lib/python3.12/ssl.py:1105, in SSLSocket.read(self, len, buffer)
#    1103 try:
#    1104     if buffer is not None:
# -> 1105         return self._sslobj.read(len, buffer)
#    1106     else:
#    1107         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# === M A X ===

# %%
# return maximal value of an array
def max(a):
    return -1

# %%
print(max([1, 2, 3]))
print(max([1, 2, -3]))
print(max([-1, -20, -3]))
# Out:
# -1
# -1
# -1

# %%
submit(max)
# Out:
# Congrats segev-gordin! Got it: '02-arrays-1d.max'. Gosha is happy :) 👍

# %% [markdown]
# === F I N D ===

# %%
# find first occurrence of n in array
# if found returns element's index
# if not found returns -1
def find(a, num):
    for i in range(len(a)):
        if a[i] == num:
            return i
    return -1

# %%
print(find([1, 2, 3], 2));
print(find([3, 1, 2], 3));
print(find([1, 3, 4], 2));
# Out:
# 1
# 0
# -1

# %%
submit(find)
# Out:
# Congrats segev-gordin! Got it: '02-arrays-1d.find'. Gosha is happy :) 👍

# %% [markdown]
# === F I N D - L A S T ===

# %%
# finds last occurrence of n in array
# if found returns element's index
# if not found returns -1
def findLast(a, num):
    return -1

# %%
print(find([1, 2, 3], 2))
print(find([1, 2, 2], 2))
print(find([1, 3, 4], 2))
# Out:
# 1
# 1
# -1

# %%
submit(findLast)
# Out:
# Congrats segev-gordin! Got it: '02-arrays-1d.findLast'. Gosha is happy :) 👍

# %% [markdown]
# === I S - P A L I N D R O M E ===

# %%
# Function returns True if input string is palidrome
# and False if not
def isPalindrome(a):
    return False

# %%
# WRITE TESTS FOR PALINDROME FUNCTION

# %%
submit(isPalindrome)
# Out:
# function 'isPalindrome()' is not part of this lesson

# %% [markdown]
# === S T A R T S - W I T H ===

# %%
# Check if array starts with another array - prefix
def startsWith(a, prefix):
    return False

# %%
# WRITE TESTS FOR startsWith

# %%
submit(startsWith)
# Out:
# Congrats segev-gordin! Got it: '02-arrays-1d.startsWith'. Gosha is happy :) 👍

# %% [markdown]
# === E N D S - W I T H ===

# %%
# Check if array ends with another array - suffix
def endsWith(a, suffix):
    return False

# %%
# WRITE TESTS FOR endsWith

# %%
submit(endsWith)
# Out:
# Congrats segev-gordin! Got it: '02-arrays-1d.endsWith'. Gosha is happy :) 👍
