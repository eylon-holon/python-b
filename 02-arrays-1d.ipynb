# %%
from eylon.core import *

start({
    "min()": [], 
    "max()": [], 
    "find()": [], 
    "findLast()": [], 
    "isPalidrome()": [], 
    "startsWith()": [], 
    "endsWith()": []
})
# Out:
# Hi lian-aharon 😁! Let's start the lesson... 🙌

# %% [markdown]
# === M I N ===

# %%
# return minimal value of an array
def min(a):
    m = a[0]
    for n in a:
        if n < m:
            m = n
    return m

# %%
print(min([1, 2, 3]))
print(min([1, 2, -3]))
print(min([-1, -20, -3]))
# Out:
# 1
# -3
# -20

# %%
submit(min)
# Out:
# Congrats lian-aharon! Got it: '02-arrays-1d.min'. Gosha is happy :) 👍

# %% [markdown]
# === M A X ===

# %%
# return maximal value of an array
def max(a):
    max=a[0]
    for num in a:
        if num>max:
            max=num
    return max

# %%
print(max([1, 2, 3]))
print(max([1, 2, -3]))
print(max([-1, -20, -3]))
# Out:
# 3
# 2
# -1

# %%
submit(max)
# Out:
# Congrats lian-aharon! Got it: '02-arrays-1d.max'. Gosha is happy :) 👍

# %% [markdown]
# === F I N D ===

# %%
# find first occurrence of n in array
# if found returns element's index
# if not found returns -1
def find(a, num):
    for i in range(len(a)):
        if a[i] == num:
            return i
    return -1

# %%
print(find([1, 2, 3], 2));
print(find([3, 1, 2], 3));
print(find([1, 3, 4], 2));
# Out:
# 1
# 0
# -1

# %%
submit(find)
# Out:
# Congrats lian-aharon! Got it: '02-arrays-1d.find'. Gosha is happy :) 👍

# %% [markdown]
# === F I N D - L A S T ===

# %%
# finds last occurrence of n in array
# if found returns element's index
# if not found returns -1
def findLast(a, num):
    return -1

# %%
print(find([1, 2, 3], 2))
print(find([1, 2, 2], 2))
print(find([1, 3, 4], 2))
# Out:
# 1
# 1
# -1

# %%
submit(findLast)
# Out:
# Congrats lian-aharon! Got it: '02-arrays-1d.findLast'. Gosha is happy :) 👍

# %% [markdown]
# === I S - P A L I N D R O M E ===

# %%
# Function returns True if input string is palidrome
# and False if not
def isPalidrome(a):
    for i in range(len(a)):
        if a[i] != a[len(a)-i-1]:
            return False
    return True

# %%
# WRITE TESTS FOR PALINDROME FUNCTION
print(isPalidrome([1,2,3,4,4,3,2,1]))
# Out:
# True

# %%
submit(isPalidrome)
# Out:
# Congrats lian-aharon! Got it: '02-arrays-1d.isPalidrome'. Gosha is happy :) 👍

# %% [markdown]
# === S T A R T S - W I T H ===

# %%
# Check if array starts with another array - prefix
def startsWith(a,b):
    for i in range(a,len(b),1):
        if a[i]!=b[1]:
            return False
    return True

# %%
# WRITE TESTS FOR startsWith

# %%
submit(startsWith)
# Out:
# Congrats lian-aharon! Got it: '02-arrays-1d.startsWith'. Gosha is happy :) 👍

# %% [markdown]
# === E N D S - W I T H ===

# %%
# Check if array ends with another array - suffix
def endsWith(a, suffix):
    return False

# %%
# WRITE TESTS FOR endsWith

# %%
submit(endsWith)
