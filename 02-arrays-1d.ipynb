# %%
from eylon.core import *

start({
    "min()": [], 
    "max()": [], 
    "find()": [], 
    "findLast()": [], 
    "isPalidrome()": [], 
    "startsWith()": [], 
    "endsWith()": []
})
# Out:
# Hi ronalee-partuk 😁! Let's start the lesson... 🙌

# %% [markdown]
# === M I N ===

# %%
# return minimal value of an array
def min(a):
    min = a[0]
    for num in a:
        if num < min:
            min = num
    return min

# %%
print(min([1, 2, 3]))
print(min([1, 2, -3]))
print(min([-1, -20, -3]))
# Out:
# 1
# -3
# -20

# %%
submit(min)
# Out:
# Congrats ronalee-partuk! Got it: '02-arrays-1d.min'. Gosha is happy :) 👍

# %% [markdown]
# === M A X ===

# %%
# return maximal value of an array
def max(a):
    max=a[0]
    for num in a:
       if num > max:
        max = num
    return max

# %%
print(max([1, 2, 3]))
print(max([1, 2, -3]))
print(max([-1, -20, 3 ]))
# Out:
# 3
# 2
# 3

# %%
submit(max)
# Out:
# Congrats ronalee-partuk! Got it: '02-arrays-1d.max'. Gosha is happy :) 👍

# %% [markdown]
# === F I N D ===

# %%
# find first occurrence of n in array
# if found returns element's index
# if not found returns -1
def find(a, num):
    for i in range(len(a)-1,-1,-1):
        if a[i] == num:
            return i
    return -1

# %%
print(find([1, 2, 3], 2));
print(find([3, 1, 2], 3));
print(find([1, 3, 4], 2));
# Out:
# 1
# 0
# -1

# %%
submit(find)
# Out:
# Congrats ronalee-partuk! Got it: '02-arrays-1d.find'. Gosha is happy :) 👍

# %% [markdown]
# === F I N D - L A S T ===

# %%
# finds last occurrence of n in array
# if found returns element's index
# if not found returns -1
def findLast(a, num):
    for i in range(len(a)-1,-1,-1):
        if a [i]== num:
            return i
    return -1

# %% [markdown]
# === I S - P A L I N D R O M E ===

# %%
def isPalindrome(a)
# Out:
#   Cell In[14], line 1
#     def isPalindrome(a)
#                        ^
# SyntaxError: expected ':'

# %%
# WRITE TESTS FOR PALINDROME FUNCTION

# %%
submit(isPalindrome)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 submit(isPalindrome)
#
# NameError: name 'isPalindrome' is not defined

# %% [markdown]
# === S T A R T S - W I T H ===

# %%
# Check if array starts with another array - prefix
def startsWith(aix):
    return False

# %%
# WRITE TESTS FOR startsWith

# %%
submit(startsWith)
# Out:
# Congrats ronalee-partuk! Got it: '02-arrays-1d.startsWith'. Gosha is happy :) 👍

# %% [markdown]
# === E N D S - W I T H ===

# %%
# Check if array ends with another array - suffix
def endsWith(a, suffix):
    return False

# %%
# WRITE TESTS FOR endsWith

# %%
submit(endsWith)
# Out:
# Congrats ronalee-partuk! Got it: '02-arrays-1d.endsWith'. Gosha is happy :) 👍
